# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json

# Import API key
from config import api_key1, api_key2

# Input File (CSV) and initilize the dataframe to fill out with yelp data
input_data_file = "restaurants.csv"
restaurant_df = pd.read_csv(input_data_file)

yelp_df = pd.DataFrame({"restaurant": restaurant_df["business_name"], 
                        "address": restaurant_df["business_address"],
                        "recent_health_score": restaurant_df["recent_score"],
                        "recent_health_risk": restaurant_df["recent_risk"],
                        "average_health_score": restaurant_df["average_score"]})
yelp_df["zipcode"] = ""
yelp_df["yelp_business_id"] = ""
yelp_df["rating"] = "" 
yelp_df["price"] = ""
yelp_df["review_count"] = ""
yelp_df["category_1"] = "" 
yelp_df["category_2"] = "" 
yelp_df["category_3"] = "" 
yelp_df["distance"] = ""

number = yelp_df["restaurant"].count()
print(f"Restaurants in SF with Health Scores: {number}")
yelp_df.head()
# Out:
# Restaurants in SF with Health Scores: 599
#           restaurant             address  recent_health_score  \
# 0      One Waan Thai     2922 Diamond St                   96
# 1      Project juice       506 Castro St                   98
# 2     Seismic Coffee       298 Market St                   90
# 3     Seismic Coffee       598 Market St                   96
# 4  Smitten Ice Cream  432 Octavia St #1a                   96
#
#   recent_health_risk  average_health_score zipcode yelp_business_id rating  \
# 0      Moderate Risk             96.666667
# 1           Low Risk             78.250000
# 2      Moderate Risk             88.500000
# 3           Low Risk             96.000000
# 4      Moderate Risk             98.000000
#
#   price review_count category_1 category_2 category_3 distance
# 0
# 1
# 2
# 3
# 4

# %%
url = "https://api.yelp.com/v3/businesses/search?"

headers = {'Authorization': 'Bearer %s' % api_key1}
params = {"term": "restaurant",
          "location": "address",
          "categories": "restaurants",
          "radius": 25,
          "limit": 1}

print("---------------------------")
print("Beginning API calls to Yelp")
print("---------------------------")

# Loop through to get all the restaurants
# use iterrows to iterate through pandas dataframe
for index, row in yelp_df.iterrows():
    # restaurant and address
    params["term"] = row['restaurant']
    params["location"] = row['address'] + ", " + "San Francisco, CA"

    print(f"processing record {index}, {params['term']}")
    # Make the request
    business_data = requests.get(url, params=params, headers=headers).json()
    
    # Use Try/Except to fill out the data.  Not all data may be available.
    try:
        yelp_df.loc[index, 'yelp_business_id'] = business_data["businesses"][0]["id"]
          
        try:
            yelp_df.loc[index, 'rating'] = business_data["businesses"][0]["rating"]
        except(KeyError, IndexError):
            yelp_df.loc[index, 'rating'] = ""
          
        try:
            yelp_df.loc[index, 'review_count'] = business_data["businesses"][0]["review_count"]
        except(KeyError, IndexError):
            yelp_df.loc[index, 'review_count'] = ""  
          
        try:
            yelp_df.loc[index, 'distance'] = business_data["businesses"][0]["distance"]
        except(KeyError, IndexError):
            yelp_df.loc[index, 'distance'] = ""
          
        try:
            yelp_df.loc[index, 'price'] = business_data["businesses"][0]["price"]
        except(KeyError, IndexError):
            yelp_df.loc[index, 'price'] = ""
          
        try:
            yelp_df.loc[index, "zipcode"] = business_data["businesses"][0]["location"]["zip_code"]
        except(KeyError, IndexError):
            yelp_df.loc[index, "zipcode"] = ""
          
        try:
            yelp_df.loc[index, 'category_1'] = business_data["businesses"][0]["categories"][0]["title"]
            yelp_df.loc[index, 'category_2'] = business_data["businesses"][0]["categories"][1]["title"]
            yelp_df.loc[index, 'category_3'] = business_data["businesses"][0]["categories"][2]["title"]
        except (KeyError, IndexError):
            yelp_df.loc[index, 'category_3'] = ""
          
    # If there is no "yelp_business_id", there is no yelp data 
    # so we set that value to "NaN", later the row can be removed.
    except(KeyError, IndexError):
        print("Restaurant not found... skipping.")
        yelp_df.loc[index, 'yelp_business_id'] = float("nan")
          
    if index == 4000:
        print("Reached maximum calls, starting group 2:")
        # We are only allowed 5000 calls to yelp per day so we have a second key to
        # finish processes the 5000+ restaurants.
        headers = {'Authorization': 'Bearer %s' % api_key2}
          
print("---------------------------")
print("All restaurants processed!!")
print("---------------------------")
# Out:
# ---------------------------
# Beginning API calls to Yelp
# ---------------------------
# processing record 0, One Waan Thai
# processing record 1, Project juice
# processing record 2, Seismic Coffee
# processing record 3, Seismic Coffee
# processing record 4, Smitten Ice Cream
# processing record 5, Glena's
# processing record 6, Blue Bottle Coffee
# processing record 7, Korean Bobcha
# processing record 8, Barry's Bootcamp
# processing record 9, La Boulange de San Francisco
# processing record 10, The Bindery
# processing record 11, Milkbean
# processing record 12, Zaoh Restaurant
# processing record 13, Corks
# processing record 14, Overtime
# processing record 15, The Organic Coup
# processing record 16, CafeLambretta
# processing record 17, Big Fish Little Fish Poke
# processing record 18, Mi Lindo Peru
# processing record 19, Homegrown Sustainable Sandwiches
# processing record 20, Thomas Edison Charter Academy
# processing record 21, Manila Bowl
# processing record 22, Frena
# processing record 23, Hawker Fare
# processing record 24, UMA Casa
# processing record 25, Flores
# processing record 26, CRABSTERS
# processing record 27, Parker
# processing record 28, Tang Collection
# processing record 29, Ushio Ramen
# processing record 30, Stop-N-Wrap
# processing record 31, El Rinconcito Catracho
# processing record 32, Mission Asia Noodle
# processing record 33, Fermentation Lab
# processing record 34, King Kee
# processing record 35, Sheraton Fisherman's Wharf Hotel
# processing record 36, Planet Cafe
# processing record 37, Let's Roll
# processing record 38, The Riddler
# processing record 39, Red Sea Pizza and Market
# processing record 40, Poke Origin
# processing record 41, Pakwan Restaurant
# processing record 42, Vegan Picnic
# processing record 43, Henry's Hunan Restaurant
# processing record 44, Souvla
# processing record 45, Noeteca
# processing record 46, Laundre
# processing record 47, Sharetea
# processing record 48, Grill Restaurant & Lobby Bar
# processing record 49, St. Regis Hotel San Francisco Main Kitchen
# processing record 50, Mama Lamees
# processing record 51, Hermanos Coffee & Juice Bar
# processing record 52, Atlas Tap Room
# processing record 53, Rusted Mule
# processing record 54, Neighbor Bakehouse
# processing record 55, San Francisco Marriott Fisherman's Wharf
# processing record 56, The Spicy Shrimp
# processing record 57, Salt & Straw - Fillmore
# processing record 58, Rooh
# processing record 59, Ming Hui Dim Sum
# processing record 60, Saltroot Cafe
# processing record 61, Kingza
# processing record 62, Senor Sisig (#6)
# processing record 63, The Melt
# processing record 64, Heritage
# processing record 65, Iza Ramen
# processing record 66, The ARC San Francisco
# processing record 67, Pho Dong Huong
# processing record 68, Win's Restaurant
# processing record 69, Alba Ray's
# processing record 70, Norcina
# processing record 71, Swamp Restaurant
# processing record 72, Streamline
# processing record 73, Trader Joe's #225
# processing record 74, Coast Poke Counter
# processing record 75, Zita
# processing record 76, Tahini
# processing record 77, BeQue Restaurant
# processing record 78, Blue Barn Gourmet
# processing record 79, Herb N Kitchen
# processing record 80, Sf Hilton Employee Cafe
# processing record 81, Urban Tavern
# processing record 82, McDonald's
# processing record 83, McDonald's
# processing record 84, McDonald's
# processing record 85, McDonald's
# processing record 86, SF Hilton Pastry Bakery Kitchen
# processing record 87, SF Hilton Main Kitchen
# processing record 88, Cityscape Bar & Lounge
# processing record 89, SF Hilton Banquet Facilities
# processing record 90, Lin's Kitchen
# processing record 91, The Pork Exchange
# processing record 92, The Boba Shop
# processing record 93, Mestiza Taqueria
# processing record 94, Mr. T Cafe
# processing record 95, Caffe Sapore
# processing record 96, Enough Tea & Coffee
# processing record 97, Lone Star Saloon
# processing record 98, Park Gyros Castro
# processing record 99, Tara Indian Cuisine
# processing record 100, Pink Onion
# processing record 101, Le Marais Bakery Castro
# processing record 102, Western Donut
# processing record 103, Andronica's Community Markets
# processing record 104, Puppy Bobar
# processing record 105, Brown Sugar Factory
# processing record 106, Biondivino
# processing record 107, Media Noche
# processing record 108, Mixt Greens/Mixt
# processing record 109, Caffe Capriccio
# processing record 110, Tekka House
# processing record 111, The Sea Star
# processing record 112, Noon-All Day
# processing record 113, Reina's Restaurant
# processing record 114, Taqueria Los Amigos
# processing record 115, B-Side
# processing record 116, Kitava
# processing record 117, Baron's Quality Meat & Seafood
# processing record 118, The Douglas Room
# processing record 119, Chef's Work in the Truck
# processing record 120, Club Deluxe
# processing record 121, Hawaiian Drive Inn #28
# processing record 122, Hook Fish Company
# processing record 123, Pushkin
# processing record 124, Petit Marlowe
# processing record 125, Ikes Love & Sandwiches
# processing record 126, Pine & Taylor Market
# processing record 127, Mersea
# processing record 128, Kaisen Sushi
# processing record 129, Noe Valley Bakery
# processing record 130, Beanstalk - Inner Richmond
# processing record 131, Steep Creamery & Tea
# processing record 132, Namu Stonepot
# processing record 133, Om Indian Cuisine
# processing record 134, Andytown Coffee Roasters
# processing record 135, Ladle & Leaf
# processing record 136, Jiffy Dog
# processing record 137, Creative Ideas Catering SF
# processing record 138, Blue Bottle Coffee
# processing record 139, Bella 3848
# processing record 140, Trademark/Copyright
# processing record 141, Intercontinental Mark Hopkins
# processing record 142, Intercontinental Mark Hopkins
# processing record 143, Gorkha Kitchen
# processing record 144, Intercontinental Mark Hopkins
# processing record 145, Intercontinental Mark Hopkins
# processing record 146, Olea Restaurant
# processing record 147, Salt & Straw
# processing record 148, Jiangnan Cuisine
# processing record 149, El Azteca Taqueria
# processing record 150, Supreme Pizza
# processing record 151, Esan Classic
# processing record 152, Beard Papa's
# processing record 153, Beard Papa's
# processing record 154, Kahnfections
# processing record 155, Crown & Acre
# processing record 156, Home Cafe
# processing record 157, Panzon
# processing record 158, New York Pizza Kitchen
# processing record 159, Koja Kitchen
# processing record 160, Hazel Southern Bar and Kitchen
# processing record 161, Chef Li's Cafe
# processing record 162, Hot Sauce and Panko
# processing record 163, Chopsticks Restaurant
# processing record 164, Soma Sushi
# processing record 165, Uji Time Dessert
# processing record 166, Sababa
# processing record 167, Nourish Cafe
# processing record 168, Poke Delish
# processing record 169, Woodlands Market
# processing record 170, Les Gourmands Bakery
# processing record 171, Indian Palace
# processing record 172, Peet's Coffee and Tea
# processing record 173, RT Rotisserie
# processing record 174, Proper Food
# processing record 175, Big Rec Taproom
# processing record 176, The Meatball Bar
# processing record 177, Lime Tree
# processing record 178, Castro Ice Cream
# processing record 179, El Capitan
# processing record 180, Tiffany's Cafe
# processing record 181, An The Go
# processing record 182, Ohana Poke and Salad Bar
# processing record 183, A Mano
# processing record 184, Poke Life
# processing record 185, Lapats Thai Noodles Bar
# processing record 186, Yama Sushi Restaurant
# processing record 187, Zzan
# processing record 188, Merchant Roots
# processing record 189, New Moon Restaurant
# processing record 190, Sutter Cafe
# processing record 191, Mandarin House SF
# processing record 192, Pesce E Riso Restaurant
# processing record 193, Derm Restaurant
# processing record 194, Flore
# processing record 195, Ladle & Leaf
# processing record 196, Taqueria Los Mayas
# processing record 197, Nara Sushi
# processing record 198, Tin Vietnamese Cuisine
# processing record 199, Kui Shin Bo #2
# processing record 200, Pot & Noodle
# processing record 201, Royal Indian Cuisine
# processing record 202, Joe & The Juice
# processing record 203, Robin
# processing record 204, Amawele's South African Kitchen
# processing record 205, Swirl on Castro
# processing record 206, Hunan Home's Restaurant
# processing record 207, China North Dumpling
# processing record 208, El Gran Taco Loco
# processing record 209, Nute's
# processing record 210, Sightglass Coffee
# processing record 211, St. Cecilia School
# processing record 212, Open Kitchen
# processing record 213, Enter The Cafe
# processing record 214, Parties That Cook
# processing record 215, Barrel Proof
# processing record 216, Pho Huynh Sang
# processing record 217, Parc 55 San Francisco, a Hilton Hotel
# processing record 218, Troy Greek Cuisine
# processing record 219, Le Cupboard
# processing record 220, Roxie Food Center
# processing record 221, Lemonade
# processing record 222, Old Ship
# processing record 223, Ritual Coffee Roasters
# processing record 224, Hello Sandwich & Noodle
# processing record 225, Home Skillet SF
# processing record 226, Jake's Steaks
# processing record 227, Alma Cocina
# processing record 228, Saint Frank Coffee
# processing record 229, Max's Opera Cafe
# processing record 230, Food and Liquor World
# processing record 231, ABC Falafel
# processing record 232, Newkirk's
# processing record 233, Top Round Roast Beef
# processing record 234, Milkbomb Ice Cream
# processing record 235, Kuma Sushi + Sake
# processing record 236, Little Swan Bakery
# processing record 237, Jin Pot
# processing record 238, Ginger Elizabeth Chocolates
# processing record 239, Little Nepal
# processing record 240, Sip Tea Room
# processing record 241, Grandma's Deli and Cafe #2
# processing record 242, Tilak Indian Cuisine
# processing record 243, Emmys Spaghetti Shack
# processing record 244, Maxfield's House of Caffeine
# processing record 245, Thai Cafe
# processing record 246, Cup Cafe
# processing record 247, Alfaro Truck
# processing record 248, Kikka at Woodlands Market
# processing record 249, Uncle Joe
# processing record 250, H & L Super Market
# processing record 251, Bandit
# processing record 252, Yum Yum Sushi House
# processing record 253, San Francisco Proper Hotel
# processing record 254, San Francisco Proper Hotel
# processing record 255, San Francisco Proper Hotel
# processing record 256, San Francisco Proper Hotel
# processing record 257, Native Co.
# processing record 258, Origen
# processing record 259, SINI
# processing record 260, Tea Hut
# processing record 261, Ardiana
# processing record 262, Cafe X
# processing record 263, Khamsa
# processing record 264, Foothill Market
# processing record 265, Tato
# processing record 266, Iron Horse
# processing record 267, Luv A Java
# processing record 268, Candi Me
# processing record 269, Wok This Way
# processing record 270, Mixt Greens/Mixt
# processing record 271, Pentacle Coffee
# processing record 272, Kaiju Cooks
# processing record 273, Barnzu
# processing record 274, Ella's Cafe
# processing record 275, Taqueria Zorro
# processing record 276, Dottie's True Blue Cafe
# processing record 277, Buckhorn Grill
# processing record 278, Toy Soldier
# processing record 279, La Boulangerie De San Francisco
# processing record 280, Chennai Kings
# processing record 281, Sunflower Garden Restaurant
# processing record 282, Fleur De Sel
# processing record 283, Kusina Ni Tess
# processing record 284, Ippudo
# processing record 285, Dispensa
# processing record 286, Jasmine Tea House
# processing record 287, Vitalist Food
# processing record 288, Scotch Bonnet
# processing record 289, Flore
# processing record 290, Son's Addition
# processing record 291, OMG Tea
# processing record 292, True Laurel
# processing record 293, Sam Wo Restaurant and Bakery
# processing record 294, Clean Bites
# processing record 295, Wok Shop Cafe
# processing record 296, Nobuyuki
# processing record 297, The Civic Kitchen
# processing record 298, New World Market
# processing record 299, Cafe Reveille
# processing record 300, Toasty
# processing record 301, Foxsister
# processing record 302, La Loma Produce #8
# processing record 303, Dong Bei Mama
# processing record 304, Johnny Doughnuts
# processing record 305, Icicles
# processing record 306, Uncle Boy's
# processing record 307, Proper Food
# processing record 308, Big Lantern
# processing record 309, Kaisen Don
# processing record 310, Grill Spot
# processing record 311, The Organic Coup
# processing record 312, Wooden Spoon
# processing record 313, Thanh Thanh Cafe
# processing record 314, Jijime
# processing record 315, Wasabi Bistro
# processing record 316, Dosa Allee
# processing record 317, Tenroku Ramen
# processing record 318, Taqueria Gonzalez
# processing record 319, Lotus SF
# processing record 320, TS Cafe
# processing record 321, Joe & The Juice 2213 Fillmore
# processing record 322, Bluestone Lane
# processing record 323, My Cup of Tea
# processing record 324, Pizza Squared
# processing record 325, Bizza
# processing record 326, Thai Idea Vegetarian
# processing record 327, Las Palmas on SF
# processing record 328, Hidden Star Orchards
# processing record 329, Native Burger
# processing record 330, Sean's Market Cafe
# processing record 331, Tuba Restaurant
# processing record 332, Marugame Udon
# processing record 333, Outer Orbit
# processing record 334, Smoky Man
# processing record 335, Nook
# processing record 336, Cilantro SF Taqueria
# processing record 337, Papito
# processing record 338, The Snug
# processing record 339, Boos Voni
# processing record 340, Earth's Coffee
# processing record 341, Native Twins Coffee
# processing record 342, Little Heaven Deli
# processing record 343, Gio Gelati
# processing record 344, Japanese House
# processing record 345, Doughp
# processing record 346, Wholesome Bakery
# processing record 347, Krispy Krunchy Chicken
# processing record 348, Royal Ground coffee
# processing record 349, Hodala Restaurant
# processing record 350, I'A Poke
# processing record 351, Parkside Market
# processing record 352, Lokma
# processing record 353, KIPP Bayview Academy
# processing record 354, Pollo Campero
# processing record 355, Center for Academic Re-entry and Empowerment
# processing record 356, Tawara
# processing record 357, The Game Parlour
# processing record 358, GO GO 7
# processing record 359, Wago Sushi
# processing record 360, Seokyo
# processing record 361, Freshroll
# processing record 362, Phonobar
# processing record 363, Our Poke Place
# processing record 364, Stonemill Matcha
# processing record 365, Boba Guys
# processing record 366, IKU Sushi
# processing record 367, Spice of America
# processing record 368, Choux
# processing record 369, Takoba SF
# processing record 370, Howells
# processing record 371, Sugoi Sushi
# processing record 372, Sunshine Wheatfield Dim Sum
# processing record 373, DNM Hot Pot
# processing record 374, Chanvi
# processing record 375, Birdsong
# processing record 376, Rosamunde Sausage Grill
# processing record 377, Matcha Cafe Maiko
# processing record 378, Mayah's Restaurant Cafe
# processing record 379, Hayes Valley Bakeworks
# processing record 380, Powder
# processing record 381, Foundation Cafe
# processing record 382, Kokio Republic
# processing record 383, Sizzling Pot King
# processing record 384, Braised + Bread
# processing record 385, Simply Cafe
# processing record 386, Papi's SF
# processing record 387, New Fortune Restaurant
# processing record 388, Poke Bar
# processing record 389, Joe & The Juice Howard
# processing record 390, Cafe Josephine
# processing record 391, Ocean Thai
# processing record 392, Latte Express #3
# processing record 393, There Sushi-Bar & Restaurant
# processing record 394, Lapisara Eatery
# processing record 395, FK Frozen Custard
# processing record 396, Orchids Cafe
# processing record 397, Sorrel Restaurant
# processing record 398, U Dessert Story
# processing record 399, Happy Donuts
# processing record 400, Sidewalk Juice
# processing record 401, 94644 Derby Grill
# processing record 402, 94652 Gilroy Garlic Fries
# processing record 403, 94673 Great House of Brews
# processing record 404, Navin Thai Restaurant
# processing record 405, Hotel San Francisco
# processing record 406, The Cheese Steak Shop
# processing record 407, People's Bistro
# processing record 408, Rooster & Rice
# processing record 409, The Sausage Factory
# processing record 410, Indo
# processing record 411, Breaking Bread
# processing record 412, Nico
# processing record 413, Qualitea
# processing record 414, Bryant Shell
# processing record 415, DeliMan
# processing record 416, Violet's
# processing record 417, Kantine
# processing record 418, Pine Tar Grill and Bar
# processing record 419, Casa De La Condesa Restaurant
# processing record 420, Internos Wine Cafe and Bar
# processing record 421, Wing Lee Bakery
# processing record 422, Ike's Kitchen
# processing record 423, Valenciano
# processing record 424, 94939 Gilroy Garlic
# processing record 425, Lush Gelato
# processing record 426, Fritz Mission
# processing record 427, Ace King BBQ
# processing record 428, Toyama Japanese Restaurant
# processing record 429, 94971 Gilroy Garlic Stand
# processing record 430, 94983 Chowder House
# processing record 431, 94884 Great House of Brews
# processing record 432, Naya Cafe
# processing record 433, Sultan's Kebab
# processing record 434, CABLE CAR COFFEE
# processing record 435, Wing Wings
# processing record 436, Sakesan
# processing record 437, Rose Kitchen
# processing record 438, R Caffe
# processing record 439, Pearl
# processing record 440, Sidewalk Juice
# processing record 441, Bay Subs & Deli
# processing record 442, Mangal Mediterranean Restaurant
# processing record 443, Beer Nerds
# processing record 444, Hi-Way
# processing record 445, Aroma Tea Shop
# processing record 446, Equator Coffees
# processing record 447, Greaser Coffee
# processing record 448, 95202 Mission Street Nacho Cart
# processing record 449, 95229 Outta Here Cheesesteak
# processing record 450, 95245 Doggie Diner/Taqueria
# processing record 451, 1608 Bistro
# processing record 452, Toppu Ramen & Dim Sum House
# processing record 453, Back Room
# processing record 454, The Rainbow
# processing record 455, Blue Fog Market
# processing record 456, The Fog Lifter Cafe
# processing record 457, Bake Cheese Tart
# processing record 458, Bing & Boba
# processing record 459, Gong Cha
# processing record 460, Mixt Greens / Mixt
# processing record 461, T Cup Cafe
# processing record 462, SF Hole in The Wall Pizza
# processing record 463, Eat Sushi
# processing record 464, Golden Coffee
# processing record 465, Cracked & Battered
# processing record 466, Karma Cafe
# processing record 467, Altalena Vinoteca
# processing record 468, Z Zoul Cafe
# processing record 469, Urban Ritual
# processing record 470, Cafe Guatemalteco
# processing record 471, Phillmore Creamery
# processing record 472, Otoro
# processing record 473, Mustafio"s Pizza
# processing record 474, Joe & The Juice- 303 2nd Street
# processing record 475, Spice Kitchen
# processing record 476, Neighbors Corner
# processing record 477, Canopy
# processing record 478, Double Decker
# processing record 479, Mainland Market
# processing record 480, Ichiraku Ramen
# processing record 481, Anton's Pizza
# processing record 482, Z & Y Bistro
# processing record 483, Irving Pizza
# processing record 484, Crave Subs
# processing record 485, The Korean Kitchen
# processing record 486, STONE KOREAN KITCHEN
# processing record 487, Black Sugar
# processing record 488, Poke Delish
# processing record 489, Sightglass Coffee
# processing record 490, DIJON BURGER
# processing record 491, Fig & Thistle Market
# processing record 492, Alembic, SF
# processing record 493, THE SALAD PLACE & ROTISSERIE
# processing record 494, TARARA
# processing record 495, El Rancho Grande Taqueria
# processing record 496, Crepe & Curry
# processing record 497, Heavenly Cafe
# processing record 498, Golden State Grill
# processing record 499, Panchitas
# processing record 500, SAJJ``
# processing record 501, Mauer Park
# processing record 502, HARVEST WHEATFIELD BAKERY
# processing record 503, DOUGLAS
# processing record 504, SANPPO RESTAURANT
# processing record 505, COCO FRESH TEA & JUICE
# processing record 506, THE LUCKY PIG
# processing record 507, KKOCHI KOREAN BBQ RESTAURANT
# processing record 508, LUKE'S LOBSTER
# processing record 509, GOCHEES PIZZA
# processing record 510, SUSHI SHOH
# processing record 511, JOE & THE JUICE - 1155 4TH STREET
# processing record 512, VAN NESS CAFE & GYROS
# processing record 513, OCEAN BLUE LAUNDRY & CAFE
# processing record 514, VENUS CAFE
# processing record 515, JASPER'S CORNER TAP & KITCHEN
# processing record 516, SAN FRANCISCO WINE AND CHEESE
# processing record 517, MAI MAI SANDWICH & BAKERY
# processing record 518, HAKKA RESTAURANT
# processing record 519, Cups and Cakes Bakery
# processing record 520, The Story of Ramen
# processing record 521, LEFTYS BALLPARK BUFFET
# processing record 522, EL CAFE
# processing record 523, PALACE OF SPICES
# processing record 524, CAPTAIN KONA CAFE
# processing record 525, SNOW GARDEN EXPRESS
# processing record 526, PRESIDIO PIZZA COMPANY
# processing record 527, WORD A CAFE
# processing record 528, Caffea
# processing record 529, MR. EAST KITCHEN
# processing record 530, LOVESSY
# processing record 531, MENDOCINO FARMS
# processing record 532, HARDWOOD BAR & SMOKERY
# processing record 533, FREDS AT BARNEYS NEW YORK
# processing record 534, FRENA
# processing record 535, MANNY'S
# processing record 536, DOPPIO ZERO
# processing record 537, CHOMP N' SWIG
# processing record 538, TROJE
# processing record 539, KAIYO RESTAURANT & BAR
# processing record 540, OYE MANAGUA
# processing record 541, HAPPY DONUTS
# processing record 542, GREAT MONGOLIA
# processing record 543, TOSAI
# processing record 544, EL PIPILA
# processing record 545, IZUMI KAITEN SUSHI
# processing record 546, ASHLEY'S CAFE
# processing record 547, PRAIRIE
# processing record 548, KIBATSU
# processing record 549, PIRI PICA
# processing record 550, FAT BELI DELI
# processing record 551, SHIHLIN
# processing record 552, VEGAN-N-KABOB
# processing record 553, ELIXART
# processing record 554, MANSION ON SUTTER
# processing record 555, THE ITALIAN HOMEMADE COMPANY
# processing record 556, PUSHCART FARE
# processing record 557, FISTFUL OF TACOS
# processing record 558, LITTLE SUSHI BAR
# processing record 559, HOUSE OF BAGELS AT MASON
# processing record 560, ARAMEX
# processing record 561, MUGUBOKA RESTAURANT
# processing record 562, AN CHI
# processing record 563, HOT SPUD
# processing record 564, GAI
# processing record 565, PIZZERIA DELFINA
# processing record 566, PING & YANG
# processing record 567, NOMMO
# processing record 568, BREADBELLY
# processing record 569, Sumo
# processing record 570, HON'S WUN TUN HOUSE
# processing record 571, BAZAAR CAFE
# processing record 572, TASTY RESTAURANT
# processing record 573, PHO 335
# processing record 574, BLUESTONE LANE
# processing record 575, USAGI
# processing record 576, TY PHO
# processing record 577, ST. THOMAS MORE ELEMENTARY SCHOOL
# processing record 578, BIG CITY MONTESSORI SCHOOL
# processing record 579, ZHUO KITCHEN
# processing record 580, LAGUNA
# processing record 581, SWEET MANGO DESSERT & CAFE
# processing record 582, TWO SONS SANDWICHES
# processing record 583, JANCHAY'S BISTRO.
# processing record 584, MANGO CRAZY
# processing record 585, CROSSROAD PIZZERIA
# processing record 586, THE LINKS BAR AND GRILL
# processing record 587, TAYLOR LANE ORGANIC COFFEE
# processing record 588, BLUESTONE LANE
# processing record 589, POMELO ON CHURCH
# processing record 590, LING LING CUISINE RESTAURANT
# processing record 591, KRISPY KRUNCHY CHICKEN
# processing record 592, THE BAGEL BAKERY CAFE
# processing record 593, LOVING CUP OCTAVIA
# processing record 594, HAPPY DONUTS
# processing record 595, ONE BOILING POT
# processing record 596, B & B CAFE
# processing record 597, Marley's Streats
# processing record 598, GOLDEN STATE PIZZA AND GRILL
# ---------------------------
# All restaurants processed!!
# ---------------------------

# %%
yelp_df.count()
# Out:
# restaurant              599
# address                 599
# recent_health_score     599
# recent_health_risk      545
# average_health_score    599
# zipcode                 599
# yelp_business_id        599
# rating                  599
# price                   599
# review_count            599
# category_1              599
# category_2              599
# category_3              599
# distance                599
# dtype: int64

# %%
yelp_df = yelp_df.dropna(subset=['yelp_business_id'])
yelp_df.count()
# Out:
# restaurant              599
# address                 599
# recent_health_score     599
# recent_health_risk      545
# average_health_score    599
# zipcode                 599
# yelp_business_id        599
# rating                  599
# price                   599
# review_count            599
# category_1              599
# category_2              599
# category_3              599
# distance                599
# dtype: int64

# %%
# Export file as a CSV, without the Pandas index, but with the header
yelp_df.to_csv("yelp_ratings.csv", index=False, header=True)
