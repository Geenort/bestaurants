# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import polyfit
import scipy.stats as stats

# %%
file1 = "Resources/median_income_by_zip_code.csv"

# %%
df1 = pd.read_csv(file1, encoding='utf-8')

# %%
df1.head()
# Out:
#    zip_code  income
# 0      1001  56,663
# 1      1002  49,853
# 2      1003  28,462
# 3      1005  75,423
# 4      1007  79,076

# %%
df1['zip_code'] = df1['zip_code'].astype(str)

# %%
file2 = "Resources/restaurant_scores.csv"

# %%
df2 = pd.read_csv(file2, encoding='utf-8')

# %%
df2_limited_columns = df2[['business_name', 'business_postal_code', 'inspection_score']]
restaurantscleaned = df2_limited_columns.dropna(how='any')
restaurantscleaned.head()
# Out:
#                      business_name business_postal_code  inspection_score
# 0              Soo Fong Restaurant                94124              92.0
# 1  Dar Bar Pakistani/Indian Cusine                94109              86.0
# 2           Wise Sons Delicatessen                94102              92.0
# 3        DRAGON CITY BAKERY & CAFE                94110              84.0
# 4                          Deli 23                94110              92.0

# %%
avgscore = restaurantscleaned.groupby('business_postal_code', as_index=False).mean()

# %%
avgscore.head()
# Out:
#   business_postal_code  inspection_score
# 0                00000              93.0
# 1                64110              85.0
# 2                92672              87.0
# 3                94013              96.0
# 4                94014              98.0

# %%
zipvalcounts = pd.DataFrame(restaurantscleaned['business_postal_code'].value_counts())
zipvalcounts_cleaned = zipvalcounts.reset_index()
zipvalcounts_cleaned.head()
# Out:
#    index  business_postal_code
# 0  94110                  4450
# 1  94103                  3405
# 2  94133                  3014
# 3  94109                  3000
# 4  94102                  2759

# %%
ziprenamed = zipvalcounts_cleaned.rename(index=str, columns={"index": "zip_code", "business_postal_code": "inspection_count"})
ziprenamed.head()
# Out:
#   zip_code  inspection_count
# 0    94110              4450
# 1    94103              3405
# 2    94133              3014
# 3    94109              3000
# 4    94102              2759

# %%
avgscore_formerge = avgscore.rename(index=str, columns={"business_postal_code": "zip_code"})
avgscore_formerge['zip_code'] = avgscore_formerge['zip_code'].astype(str)
avgscore_formerge.head()
# Out:
#   zip_code  inspection_score
# 0    00000              93.0
# 1    64110              85.0
# 2    92672              87.0
# 3    94013              96.0
# 4    94014              98.0

# %%
df_fordrop = pd.merge(avgscore_formerge, df1, on="zip_code", how="left")
df_fordrop.head()
# Out:
#   zip_code  inspection_score  income
# 0    00000              93.0     NaN
# 1    64110              85.0  41,624
# 2    92672              87.0  71,928
# 3    94013              96.0     NaN
# 4    94014              98.0  75,187

# %%
df_cleaned = df_fordrop.dropna(how='any')
df_cleaned['income'] = df_cleaned['income'].replace(",","", regex=True).astype(float)
df_sorted = df_cleaned.sort_values(by='income', ascending=True)
# Out:
# C:\Users\Iam\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.scatter(df_sorted['income'], df_sorted['inspection_score'], marker="o", facecolors="red", edgecolors="black",
            s=40, alpha=0.75)
plt.xticks(rotation=90)
plt.xlabel('Median Household Income (2006-2010)')
plt.ylabel('Average Health Inspection Score')
plt.title('Income vs. Health Inspection Score')
plt.xlim(0, 160000)
plt.tight_layout()
plt.savefig("ScatterUniformSize.png")

# %%
mergewithcount = pd.merge(df_sorted, ziprenamed, on="zip_code", how="left")
mergewithcount.head()
# Out:
#   zip_code  inspection_score   income  inspection_count
# 0    94104         86.066590  23165.0               871
# 1    94102         86.088800  29613.0              2759
# 2    94108         84.524796  37052.0              1593
# 3    64110         85.000000  41624.0                 4
# 4    94133         86.050100  45203.0              3014

# %%
plt.scatter(mergewithcount['income'], mergewithcount['inspection_score'], marker="o", facecolors="red", edgecolors="black",
            s=mergewithcount['inspection_count']/4, alpha=0.5)
plt.xticks(rotation=90)
plt.xlabel('Median Household Income (2006-2010)')
plt.ylabel('Average Health Inspection Score')
plt.title('Income vs. Health Inspection Score')
plt.xlim(0, 160000)
plt.tight_layout()
plt.savefig("ScatterVariableSize.png")

# %%
bins = [0, 20000, 40000, 60000, 80000, 100000, 120000, 160000]
group_labels = ['0 - 20k', '20k - 40k', '40k - 60k', '60k - 80k', '80k - 100k', '100k - 120k', '120k+']
mergewithcount['income_binned'] = pd.cut(mergewithcount['income'], bins, labels=group_labels)
mergewithcount.head()
# Out:
#   zip_code  inspection_score   income  inspection_count income_binned
# 0    94104         86.066590  23165.0               871     20k - 40k
# 1    94102         86.088800  29613.0              2759     20k - 40k
# 2    94108         84.524796  37052.0              1593     20k - 40k
# 3    64110         85.000000  41624.0                 4     40k - 60k
# 4    94133         86.050100  45203.0              3014     40k - 60k

# %%
binned_income = mergewithcount.groupby('income_binned', as_index=False).sum()
binned_income
# Out:
#   income_binned  inspection_score     income  inspection_count
# 0       0 - 20k          0.000000        0.0                 0
# 1     20k - 40k        256.680186    89830.0              5223
# 2     40k - 60k        601.549286   353515.0             10989
# 3     60k - 80k       1250.414281  1019592.0             12159
# 4    80k - 100k        520.227786   552420.0              6139
# 5   100k - 120k        535.679454   653260.0              3668
# 6         120k+        185.913580   275511.0               489

# %%
plt.bar(binned_income['income_binned'], binned_income['inspection_count'], color='green', alpha=0.5, align="center")
plt.xticks(rotation=90)
plt.xlabel('Median Household Income (2006-2010)')
plt.ylabel('Number of Inspections')
plt.title('Income vs. Inspection Count')
plt.tight_layout()
plt.savefig("incomeinspectioncount.png")

# %%
file = "Resources/all_data_cleaned.csv"

# %%
df = pd.read_csv(file, encoding='utf-8')

# %%
df.head()
# Out:
#    Unnamed: 0                      restaurant              address  \
# 0           0  Norman's Ice Cream and Freezes  2801 Leavenworth St
# 1           1                        Chowders    Pier 39  Space A3
# 2           2                    XOX Truffles     754 Columbus Ave
# 3           3                     Centerfolds      391 Broadway St
# 4           4                   Caffe Puccini     411 Columbus Ave
#
#    recent_health_score recent_health_risk  average_health_score  zipcode  \
# 0                   96           Low Risk             96.000000    94133
# 1                   98           Low Risk             94.500000    94133
# 2                   94      Moderate Risk             94.000000    94133
# 3                   90           Low Risk             90.857143    94133
# 4                   90           Low Risk             90.000000    94133
#
#          yelp_business_id  rating price  review_count  \
# 0  sfAIpzEC8ywpy36YhzikmQ     4.5     $         289.0
# 1  oic-xcRpi-yXG3KZ4go0mg     3.5    $$         768.0
# 2  qkHlhvv6DrCkvY54ogcPiA     4.5     $         604.0
# 3  6Ki5PvDCebTkCRkGEXD1qw     3.5    $$         151.0
# 4  uzqUJiCHUqV2c3PnvSsqeQ     4.0     $         966.0
#
#                   category_1    category_2              category_3   distance  \
# 0  Ice Cream & Frozen Yogurt  Coffee & Tea  Juice Bars & Smoothies   8.031888
# 1                    Seafood  Fish & Chips                    Soup  57.334700
# 2       Chocolatiers & Shops  Coffee & Tea                     NaN   3.286580
# 3                    Cabaret   Strip Clubs                     NaN   7.262056
# 4               Coffee & Tea      Desserts              Sandwiches  25.578495
#
#   cuisine  median_income    zip_lat     zip_lng
# 0   Other          45203  37.804531 -122.410852
# 1   Other          45203  37.804531 -122.410852
# 2   Other          45203  37.804531 -122.410852
# 3   Other          45203  37.804531 -122.410852
# 4   Other          45203  37.804531 -122.410852

# %%
bins = [0, 20000, 40000, 60000, 80000, 100000, 120000, 160000]
group_labels = ['0 - 20k', '20k - 40k', '40k - 60k', '60k - 80k', '80k - 100k', '100k - 120k', '120k+']
df['income_binned'] = pd.cut(df['median_income'], bins, labels=group_labels)
df.head()
# Out:
#    Unnamed: 0                      restaurant              address  \
# 0           0  Norman's Ice Cream and Freezes  2801 Leavenworth St
# 1           1                        Chowders    Pier 39  Space A3
# 2           2                    XOX Truffles     754 Columbus Ave
# 3           3                     Centerfolds      391 Broadway St
# 4           4                   Caffe Puccini     411 Columbus Ave
#
#    recent_health_score recent_health_risk  average_health_score  zipcode  \
# 0                   96           Low Risk             96.000000    94133
# 1                   98           Low Risk             94.500000    94133
# 2                   94      Moderate Risk             94.000000    94133
# 3                   90           Low Risk             90.857143    94133
# 4                   90           Low Risk             90.000000    94133
#
#          yelp_business_id  rating price  review_count  \
# 0  sfAIpzEC8ywpy36YhzikmQ     4.5     $         289.0
# 1  oic-xcRpi-yXG3KZ4go0mg     3.5    $$         768.0
# 2  qkHlhvv6DrCkvY54ogcPiA     4.5     $         604.0
# 3  6Ki5PvDCebTkCRkGEXD1qw     3.5    $$         151.0
# 4  uzqUJiCHUqV2c3PnvSsqeQ     4.0     $         966.0
#
#                   category_1    category_2              category_3   distance  \
# 0  Ice Cream & Frozen Yogurt  Coffee & Tea  Juice Bars & Smoothies   8.031888
# 1                    Seafood  Fish & Chips                    Soup  57.334700
# 2       Chocolatiers & Shops  Coffee & Tea                     NaN   3.286580
# 3                    Cabaret   Strip Clubs                     NaN   7.262056
# 4               Coffee & Tea      Desserts              Sandwiches  25.578495
#
#   cuisine  median_income    zip_lat     zip_lng income_binned
# 0   Other          45203  37.804531 -122.410852     40k - 60k
# 1   Other          45203  37.804531 -122.410852     40k - 60k
# 2   Other          45203  37.804531 -122.410852     40k - 60k
# 3   Other          45203  37.804531 -122.410852     40k - 60k
# 4   Other          45203  37.804531 -122.410852     40k - 60k

# %%
incomevshealth = df.boxplot("recent_health_score", by="income_binned", figsize=(15, 8), grid=False)
incomevshealth.set_xlabel("Income (Binned)", fontsize=20)
incomevshealth.set_ylabel("Most Recent Health Inspection Score", fontsize=20)
plt.title("Income Vs. Health Score", fontsize=25)
plt.suptitle("")
plt.savefig("incomevshealthscoreboxplot.png")

# %%
pregroup1 = df.loc[(df["income_binned"] == "20k - 40k")]
pregroup2 = df.loc[(df["income_binned"] == "40k - 60k")]
pregroup3 = df.loc[(df["income_binned"] == "60k - 80k")]
pregroup4 = df.loc[(df["income_binned"] == "80k - 100k")]
pregroup5 = df.loc[(df["income_binned"] == "100k - 120k")]
pregroup6 = df.loc[(df["income_binned"] == "120k+")]

group1 = pregroup1['recent_health_score']
group2 = pregroup2['recent_health_score']
group3 = pregroup3['recent_health_score']
group4 = pregroup4['recent_health_score']
group5 = pregroup5['recent_health_score']
group6 = pregroup6['recent_health_score']

# %%
stats.f_oneway(group1, group2, group3, group4, group5, group6)
# Out:
# F_onewayResult(statistic=4.558454072072795, pvalue=0.000380422865116031)

# %%
#Redo of presentation charts using new cleaned dataframe

# %%
zipvalcounts = pd.DataFrame(df['zipcode'].value_counts())
zipvalcounts.head()
# Out:
#        zipcode
# 94110      374
# 94103      297
# 94102      265
# 94133      259
# 94109      244

# %%
avg_healthscore = df.groupby('zipcode').mean()
df_sorted = avg_healthscore.sort_values(by='median_income', ascending=True)
df_sorted = df_sorted.reset_index()
df_sorted
# Out:
#     zipcode  Unnamed: 0  recent_health_score  average_health_score    rating  \
# 0     94104      1725.0            89.234568             88.021733  3.771605
# 1     94102      1552.0            89.890566             89.238106  3.775472
# 2     94108      1347.5            89.868056             88.288953  3.715278
# 3     90012      3507.5            94.400000             93.961905  3.000000
# 4     94133       129.0            89.262548             88.517845  3.774131
# 5     94130      3501.0            92.333333             91.952381  4.000000
# 6     94124      2130.5            89.161290             88.927974  4.024194
# 7     94103      1914.0            88.760943             88.014189  3.843434
# 8     94134      2081.0            83.648649             83.023697  3.635135
# 9     94109      3117.5            89.245902             88.318253  3.862705
# 10    94931      3479.0            92.000000             88.750000  4.500000
# 11    94619      3513.0            98.000000             99.000000  3.000000
# 12    94112      2685.0            86.247934             85.924226  3.789256
# 13    94132      3452.0            90.941176             90.330334  3.284314
# 14    94110      1088.5            88.802139             88.698007  3.941176
# 15    94118      2542.5            86.542683             86.442942  3.902439
# 16    94115      2929.5            87.863636             87.490454  3.674242
# 17    94122       476.5            89.035714             88.745820  3.717262
# 18    94121      2405.0            86.693694             86.010849  3.860360
# 19    94117       325.5            89.611940             89.207787  3.876866
# 20    94111       671.5            91.164474             89.827736  3.700658
# 21    94116      2316.5            88.454545             88.372240  3.636364
# 22    94131       578.0            90.971429             89.347801  3.814286
# 23    94019      3514.0            92.000000             92.000000  4.000000
# 24    94107       824.5            90.279221             89.719346  3.831169
# 25    94114      3310.0            90.163121             90.684427  3.907801
# 26    94158      3489.5            91.450000             91.165522  3.625000
# 27    94123      2804.5            89.194915             88.545652  3.800847
# 28    94105      2222.5            87.950820             87.274068  3.606557
# 29    94127      3403.5            88.434783             87.665032  3.663043
# 30    94301      3478.0            81.000000             84.111111  4.500000
#
#     review_count      distance  median_income    zip_lat     zip_lng
# 0     261.691358     10.255812        23165.0  37.791412 -122.402129
# 1     566.256604      8.884341        29613.0  37.779584 -122.419339
# 2     443.708333      8.924907        37052.0  37.792016 -122.408584
# 3     239.000000     19.836691        39775.0  34.065975 -118.238642
# 4     602.525097      9.615345        45203.0  37.804531 -122.410852
# 5     214.666667      7.702219        46382.0  37.820688 -122.369537
# 6      96.951613     10.731306        49309.0  37.728895 -122.382779
# 7     445.242424     10.152261        53548.0  37.773152 -122.411164
# 8     102.081081      7.835064        58244.0  37.721046 -122.413555
# 9     515.893443      8.085413        59205.0  37.795388 -122.422444
# 10    170.000000  68725.249230        61473.0  38.325172 -122.716977
# 11     29.000000     32.317082        67254.0  37.790450 -122.140809
# 12    154.421488      6.800439        72442.0  37.720367 -122.442936
# 13    167.960784     12.861361        74071.0  37.722214 -122.484083
# 14    509.040107      8.187655        75106.0  37.750021 -122.415201
# 15    424.146341      7.677764        75724.0  37.780093 -122.462605
# 16    532.651515      8.116912        76493.0  37.785969 -122.437253
# 17    496.541667      8.379228        77483.0  37.758799 -122.485127
# 18    417.009009      7.572813        80980.0  37.776769 -122.494707
# 19    540.044776      7.735925        84802.0  37.769436 -122.447662
# 20    467.467105     12.210835        93790.0  37.799370 -122.398409
# 21    346.742424      7.139233        95090.0  37.745399 -122.486065
# 22    310.485714      8.595809        97834.0  37.745917 -122.441473
# 23    383.000000  29754.548490        98239.0  37.469453 -122.411841
# 24    500.103896     58.291750        99924.0  37.758260 -122.406044
# 25    431.390071      7.759731       103206.0  37.758059 -122.435408
# 26    276.100000     10.231388       104684.0  37.769893 -122.387011
# 27    466.127119      7.457450       104750.0  37.800934 -122.438366
# 28    497.975410     11.486422       112333.0  37.789649 -122.393067
# 29    291.673913      7.855669       127575.0  37.736027 -122.457207
# 30     30.000000  43060.988270       147936.0  37.444131 -122.149917

# %%
plt.scatter(df_sorted['median_income'], df_sorted['recent_health_score'], marker="o", facecolors="red", edgecolors="black",
            s=40, alpha=0.75)
plt.xticks(rotation=90)
plt.xlabel('Median Household Income (2006-2010)')
plt.ylabel('Average Health Inspection Score')
plt.title('Income vs. Health Inspection Score')
plt.xlim(0, 160000)
plt.tight_layout()
plt.savefig("ScatterUniformSize2.png")

# %%
ziprenamed = ziprenamed.rename(index=str, columns={"zip_code": "zipcode"})
ziprenamed.head()
# Out:
#   zipcode  inspection_count
# 0   94110              4450
# 1   94103              3405
# 2   94133              3014
# 3   94109              3000
# 4   94102              2759

# %%
ziprenamed['zipcode'] = ziprenamed['zipcode'].astype(str)
ziprenamed.head()
# Out:
#   zipcode  inspection_count
# 0   94110              4450
# 1   94103              3405
# 2   94133              3014
# 3   94109              3000
# 4   94102              2759

# %%
df_sorted['zipcode'] = df_sorted['zipcode'].astype(str)

# %%
df_withcount = pd.merge(df_sorted, ziprenamed, on="zipcode", how="left")
df_withcount.head()
# Out:
#   zipcode  Unnamed: 0  recent_health_score  average_health_score    rating  \
# 0   94104      1725.0            89.234568             88.021733  3.771605
# 1   94102      1552.0            89.890566             89.238106  3.775472
# 2   94108      1347.5            89.868056             88.288953  3.715278
# 3   90012      3507.5            94.400000             93.961905  3.000000
# 4   94133       129.0            89.262548             88.517845  3.774131
#
#    review_count   distance  median_income    zip_lat     zip_lng  \
# 0    261.691358  10.255812        23165.0  37.791412 -122.402129
# 1    566.256604   8.884341        29613.0  37.779584 -122.419339
# 2    443.708333   8.924907        37052.0  37.792016 -122.408584
# 3    239.000000  19.836691        39775.0  34.065975 -118.238642
# 4    602.525097   9.615345        45203.0  37.804531 -122.410852
#
#    inspection_count
# 0             871.0
# 1            2759.0
# 2            1593.0
# 3               NaN
# 4            3014.0

# %%
bins = [0, 20000, 40000, 60000, 80000, 100000, 120000, 160000]
group_labels = ['0 - 20k', '20k - 40k', '40k - 60k', '60k - 80k', '80k - 100k', '100k - 120k', '120k+']
df_withcount['income_binned'] = pd.cut(df_withcount['median_income'], bins, labels=group_labels)
df_withcount.head()
# Out:
#   zipcode  Unnamed: 0  recent_health_score  average_health_score    rating  \
# 0   94104      1725.0            89.234568             88.021733  3.771605
# 1   94102      1552.0            89.890566             89.238106  3.775472
# 2   94108      1347.5            89.868056             88.288953  3.715278
# 3   90012      3507.5            94.400000             93.961905  3.000000
# 4   94133       129.0            89.262548             88.517845  3.774131
#
#    review_count   distance  median_income    zip_lat     zip_lng  \
# 0    261.691358  10.255812        23165.0  37.791412 -122.402129
# 1    566.256604   8.884341        29613.0  37.779584 -122.419339
# 2    443.708333   8.924907        37052.0  37.792016 -122.408584
# 3    239.000000  19.836691        39775.0  34.065975 -118.238642
# 4    602.525097   9.615345        45203.0  37.804531 -122.410852
#
#    inspection_count income_binned
# 0             871.0     20k - 40k
# 1            2759.0     20k - 40k
# 2            1593.0     20k - 40k
# 3               NaN     20k - 40k
# 4            3014.0     40k - 60k

# %%
plt.bar(df_withcount['income_binned'], df_withcount['inspection_count'], color='green', alpha=1, align="center")
plt.xticks(rotation=90)
plt.xlabel('Median Household Income (2006-2010)')
plt.ylabel('Number of Inspections')
plt.title('Income vs. Inspection Count')
plt.tight_layout()
plt.savefig("incomeinspectioncount2.png")

# %%
df_dropped = df_withcount.dropna(how='any')
df_dropped.head()
# Out:
#   zipcode  Unnamed: 0  recent_health_score  average_health_score    rating  \
# 0   94104      1725.0            89.234568             88.021733  3.771605
# 1   94102      1552.0            89.890566             89.238106  3.775472
# 2   94108      1347.5            89.868056             88.288953  3.715278
# 4   94133       129.0            89.262548             88.517845  3.774131
# 5   94130      3501.0            92.333333             91.952381  4.000000
#
#    review_count   distance  median_income    zip_lat     zip_lng  \
# 0    261.691358  10.255812        23165.0  37.791412 -122.402129
# 1    566.256604   8.884341        29613.0  37.779584 -122.419339
# 2    443.708333   8.924907        37052.0  37.792016 -122.408584
# 4    602.525097   9.615345        45203.0  37.804531 -122.410852
# 5    214.666667   7.702219        46382.0  37.820688 -122.369537
#
#    inspection_count income_binned
# 0             871.0     20k - 40k
# 1            2759.0     20k - 40k
# 2            1593.0     20k - 40k
# 4            3014.0     40k - 60k
# 5              17.0     40k - 60k

# %%
plt.scatter(df_dropped['median_income'], df_dropped['recent_health_score'], marker="o", facecolors="red", edgecolors="black",
            s=df_dropped['inspection_count']/4, alpha=0.5)
plt.xticks(rotation=90)
plt.xlabel('Median Household Income (2006-2010)')
plt.ylabel('Average Health Inspection Score')
plt.title('Income vs. Health Inspection Score')
plt.xlim(0, 160000)
plt.tight_layout()
plt.savefig("ScatterVariableSize2.png")

# %%
x = df['median_income']
y = df['recent_health_score']
b, m = polyfit(x, y, 1)
plt.plot(x, b + m * x, '-')
plt.savefig('regressionline.png')

# %%
plt.scatter(df['median_income'], df['recent_health_score'], marker="o", facecolors="red", edgecolors="black",
            s=40, alpha=0.1)
plt.xticks(rotation=90)
plt.xlabel('Median Household Income (2006-2010)')
plt.ylabel('Health Inspection Score')
plt.title('Income vs. Health Inspection Score')
plt.xlim(0, 160000)
plt.tight_layout()
plt.plot(x, b + m * x, '-')
plt.savefig("Scatterwithregressionline.png")

# %%
stats.ttest_1samp(df['recent_health_score'], df['recent_health_score'].mean())
# Out:
# Ttest_1sampResult(statistic=0.0, pvalue=1.0)

# %%
df['recent_health_score'].mean()
# Out:
# 88.98065433854907
