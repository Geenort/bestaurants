# %% [markdown]
# # Load SF Health Score ratings
# # Download Yelp API data
# # Merge and clean the data up

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import requests
import json

# Import API key
from config import api_key1, api_key2

# %% [markdown]
# ### Load the SF health score data

# %%
# Read in the restaurants and their health scores from the SF city government
input_data_file = "resources/Restaurant_Scores_-_LIVES_Standard.csv"
health_df = pd.read_csv(input_data_file)

# Shorten the dataframe down to just the columns we need:
health_sm = health_df[["business_id", "business_name", "business_address", "inspection_score", "risk_category"]]
health_sm.head()
# Out:
#    business_id                    business_name  business_address  \
# 0        67448              Soo Fong Restaurant  3801 03rd St 370
# 1         1757  Dar Bar Pakistani/Indian Cusine      1412 Polk St
# 2        93022           Wise Sons Delicatessen    537 Octavia St
# 3         4864        DRAGON CITY BAKERY & CAFE   2367 MISSION St
# 4        79782                          Deli 23      2449 23rd St
#
#    inspection_score  risk_category
# 0              92.0       Low Risk
# 1              86.0  Moderate Risk
# 2              92.0  Moderate Risk
# 3              84.0       Low Risk
# 4              92.0  Moderate Risk

# %%
# We don't need any of the data without inspection scores so drop all of those rows
health_sm = health_sm.dropna(subset=['inspection_score'])
health_sm.count()
# Out:
# business_id         39808
# business_name       39808
# business_address    39808
# inspection_score    39808
# risk_category       37804
# dtype: int64

# %%
# Group by the unique "business_id" for each restaurant
health_group = health_sm.groupby("business_id")

# Fill out the dataframe to written to file for the Yelp API:
# We will use the latest inspection score, plus average and min and max score just in case we want them later.
restaurant_df = pd.DataFrame(health_group.last())
restaurant_df = restaurant_df.rename(columns={"inspection_score":"recent_score", "risk_category":"recent_risk"})
restaurant_df["average_score"] = health_group["inspection_score"].mean()
restaurant_df["minimum_score"] = health_group["inspection_score"].min()
restaurant_df["maximum_score"] = health_group["inspection_score"].max()
restaurant_df.reset_index(inplace=True)
restaurant_df.head()
# Out:
#    business_id                       business_name  \
# 0           19               Nrgize Lifestyle Cafe
# 1           24  OMNI S.F. Hotel - 2nd Floor Pantry
# 2           31      Norman's Ice Cream and Freezes
# 3           45                 CHARLIE'S DELI CAFE
# 4           48                          ART'S CAFE
#
#                 business_address  recent_score    recent_risk  average_score  \
# 0   1200 Van Ness Ave, 3rd Floor          96.0  Moderate Risk      94.333333
# 1  500 California St, 2nd  Floor          98.0       Low Risk      98.000000
# 2            2801 Leavenworth St          96.0       Low Risk      96.000000
# 3                 3202 FOLSOM St          88.0       Low Risk      86.315789
# 4                  747 IRVING St          94.0       Low Risk      90.500000
#
#    minimum_score  maximum_score
# 0           94.0           96.0
# 1           98.0           98.0
# 2           96.0           96.0
# 3           84.0           88.0
# 4           87.0           94.0

# %%
# Export file as a CSV, without the business_id which is useless now, but with the header
restaurant_df.to_csv("resources/restaurants.csv", index=False, header=True)

# %% [markdown]
# ### Load Yelp API data

# %%
# Input File (CSV) and initilize the dataframe to fill out with yelp data
#input_data_file = "resources/restaurants.csv"
#restaurant_df = pd.read_csv(input_data_file)

yelp_df = pd.DataFrame({"restaurant": restaurant_df["business_name"], 
                        "address": restaurant_df["business_address"],
                        "recent_health_score": restaurant_df["recent_score"],
                        "recent_health_risk": restaurant_df["recent_risk"],
                        "average_health_score": restaurant_df["average_score"]})
yelp_df["zipcode"] = ""
yelp_df["yelp_business_id"] = ""
yelp_df["rating"] = "" 
yelp_df["price"] = ""
yelp_df["review_count"] = ""
yelp_df["category_1"] = "" 
yelp_df["category_2"] = "" 
yelp_df["category_3"] = "" 
yelp_df["distance"] = ""

number = yelp_df["restaurant"].count()
print(f"Restaurants in SF with Health Scores: {number}")
yelp_df.head()
# Out:
# Restaurants in SF with Health Scores: 5629
#                            restaurant                        address  \
# 0               Nrgize Lifestyle Cafe   1200 Van Ness Ave, 3rd Floor
# 1  OMNI S.F. Hotel - 2nd Floor Pantry  500 California St, 2nd  Floor
# 2      Norman's Ice Cream and Freezes            2801 Leavenworth St
# 3                 CHARLIE'S DELI CAFE                 3202 FOLSOM St
# 4                          ART'S CAFE                  747 IRVING St
#
#    recent_health_score recent_health_risk  average_health_score zipcode  \
# 0                 96.0      Moderate Risk             94.333333
# 1                 98.0           Low Risk             98.000000
# 2                 96.0           Low Risk             96.000000
# 3                 88.0           Low Risk             86.315789
# 4                 94.0           Low Risk             90.500000
#
#   yelp_business_id rating price review_count category_1 category_2 category_3  \
# 0
# 1
# 2
# 3
# 4
#
#   distance
# 0
# 1
# 2
# 3
# 4

# %%
yelp_df["restaurant"].count()
# Out:
# 5629

# %%
url = "https://api.yelp.com/v3/businesses/search?"

headers = {'Authorization': 'Bearer %s' % api_key1}
params = {"term": "restaurant",
          "location": "address",
          "categories": "restaurants",
          "radius": 25,
          "limit": 1}

print("---------------------------")
print("Beginning API calls to Yelp")
print("---------------------------")

# Loop through to get all the restaurants
# use iterrows to iterate through pandas dataframe
for index, row in yelp_df.iterrows():
    # restaurant and address
    params["term"] = row['restaurant']
    params["location"] = row['address'] + ", " + "San Francisco, CA"

    print(f"processing record {index}, {params['term']}")
    # Make the request
    business_data = requests.get(url, params=params, headers=headers).json()
    
    # Use Try/Except to fill out the data.  Not all data may be available.
    try:
        yelp_df.loc[index, 'yelp_business_id'] = business_data["businesses"][0]["id"]
          
        try:
            yelp_df.loc[index, 'rating'] = business_data["businesses"][0]["rating"]
        except(KeyError, IndexError):
            yelp_df.loc[index, 'rating'] = ""
          
        try:
            yelp_df.loc[index, 'review_count'] = business_data["businesses"][0]["review_count"]
        except(KeyError, IndexError):
            yelp_df.loc[index, 'review_count'] = ""  
          
        try:
            yelp_df.loc[index, 'distance'] = business_data["businesses"][0]["distance"]
        except(KeyError, IndexError):
            yelp_df.loc[index, 'distance'] = ""
          
        try:
            yelp_df.loc[index, 'price'] = business_data["businesses"][0]["price"]
        except(KeyError, IndexError):
            yelp_df.loc[index, 'price'] = ""
          
        try:
            yelp_df.loc[index, "zipcode"] = business_data["businesses"][0]["location"]["zip_code"]
        except(KeyError, IndexError):
            yelp_df.loc[index, "zipcode"] = ""
          
        try:
            yelp_df.loc[index, 'category_1'] = business_data["businesses"][0]["categories"][0]["title"]
            yelp_df.loc[index, 'category_2'] = business_data["businesses"][0]["categories"][1]["title"]
            yelp_df.loc[index, 'category_3'] = business_data["businesses"][0]["categories"][2]["title"]
        except (KeyError, IndexError):
            yelp_df.loc[index, 'category_3'] = ""
          
    # If there is no "yelp_business_id", there is no yelp data 
    # so we set that value to "NaN", later the row can be removed.
    except(KeyError, IndexError):
        print("Restaurant not found... skipping.")
        yelp_df.loc[index, 'yelp_business_id'] = float("nan")
          
    if index == 4000:
        print("Reached maximum calls, starting group 2:")
        # We are only allowed 5000 calls to yelp per day so we have a second key to
        # finish processesing the 5000+ restaurants.
        headers = {'Authorization': 'Bearer %s' % api_key2}
          
print("---------------------------")
print("All restaurants processed!!")
print("---------------------------")
# Out:
# ---------------------------
# Beginning API calls to Yelp
# ---------------------------
# processing record 0, Nrgize Lifestyle Cafe
# Restaurant not found... skipping.
# processing record 1, OMNI S.F. Hotel - 2nd Floor Pantry
# Restaurant not found... skipping.
# processing record 2, Norman's Ice Cream and Freezes
# Restaurant not found... skipping.
# processing record 3, CHARLIE'S DELI CAFE
# processing record 4, ART'S CAFE
# processing record 5, RHODA GOLDMAN PLAZA
# Restaurant not found... skipping.
# processing record 6, CAFE X + O
# processing record 7, Oasis Grill
# processing record 8, Chowders
# processing record 9, STARBUCKS
# Restaurant not found... skipping.
# processing record 10, OMNI S.F. Hotel - 3rd Floor Pantry
# Restaurant not found... skipping.
# processing record 11, OMNI S.F. Hotel - Employee Cafeteria
# Restaurant not found... skipping.
# processing record 12, Bon Appetit @ USF-LAW SCHOOL CAFE
# Restaurant not found... skipping.
# processing record 13, J.B.'S PLACE
# processing record 14, Vega
# processing record 15, XOX Truffles
# Restaurant not found... skipping.
# processing record 16, J & M A-1 CAFE RESTAURANT LLC
# Restaurant not found... skipping.
# processing record 17, Cable Car Corner
# processing record 18, Akiko's Sushi Bar
# processing record 19, Rue Lepic
# processing record 20, The Waterfront Restaurant
# Restaurant not found... skipping.
# processing record 21, Akikos Sushi
# processing record 22, Centerfolds
# Restaurant not found... skipping.
# processing record 23, Mint
# processing record 24, Cafe Madeleine
# processing record 25, AFC SUSHI @ MOLLIE STONE'S 2
# Restaurant not found... skipping.
# processing record 26, DEJA VU PIZZA & PASTA
# processing record 27, BUS STOP PIZZA #1
# processing record 28, CAFE COLE
# processing record 29, Ladle & Leaf
# processing record 30, RADIO HABANA
# processing record 31, TAZA WRAPS & JUICE
# Restaurant not found... skipping.
# processing record 32, COURTYARD BY MARRIOTT-STAFF KITCHEN
# Restaurant not found... skipping.
# processing record 33, ARLEQUIN
# processing record 34, BAYSIDE COFFEE SHOP
# processing record 35, SUBWAY
# processing record 36, JIM'S SMOKE SHOP
# processing record 37, CONSTANS GROCERY
# Restaurant not found... skipping.
# processing record 38, SORABOL
# processing record 39, PROGRESSIVE GROUNDS
# processing record 40, Grumpy's American Pub
# processing record 41, Caffe Puccini
# processing record 42, Gelato Classico Italian Ice
# Restaurant not found... skipping.
# processing record 43, Just Wonton
# processing record 44, MIKI RESTAURANT
# processing record 45, Toy Boat Dessert Cafe
# processing record 46, THE BEANERY INC.
# Restaurant not found... skipping.
# processing record 47, Ann's Donut Coffee Shop
# processing record 48, Marche Club of S.F.
# Restaurant not found... skipping.
# processing record 49, LOS HERMANOS
# processing record 50, ON THE BRIDGE
# processing record 51, HAI SUN RESTAURANT
# processing record 52, Ben & Jerry's
# Restaurant not found... skipping.
# processing record 53, CORSAGNA
# processing record 54, Inga Donuts
# processing record 55, PARMA RESTAURANT
# processing record 56, HAI KY MI GIA
# processing record 57, PUNJAB KABAB HOUSE
# processing record 58, BISTRO AIX
# processing record 59, Bamboo Restaurant
# processing record 60, YUKOL PLACE THAI CUISINE
# processing record 61, SUBWAY
# processing record 62, MOULIN ROUGE
# processing record 63, PACIFIC CATCH
# processing record 64, The Posh Bagel
# Restaurant not found... skipping.
# processing record 65, FIRST CUP
# processing record 66, NAPOLI PIZZA RESTAURANT
# processing record 67, WAYO
# processing record 68, TEN ICHI RESTAURANT
# processing record 69, Miyako
# processing record 70, GORDO TAQUERIA #2
# processing record 71, GIANT SCOOP
# processing record 72, RINCONSITO SALVADORENO
# Restaurant not found... skipping.
# processing record 73, ADELITA'S CAKES
# processing record 74, CAFE ELENA
# processing record 75, SUPER STAR RESTAURANT
# processing record 76, View Lounge
# processing record 77, COW HOLLOW CATERING
# Restaurant not found... skipping.
# processing record 78, HAAGEN-DAZS #561
# Restaurant not found... skipping.
# processing record 79, EL FARO
# Restaurant not found... skipping.
# processing record 80, HOUSE OF HUNAN
# processing record 81, Cafe Madeleine
# Restaurant not found... skipping.
# processing record 82, Buster's
# processing record 83, Michelangelo Caffe
# processing record 84, Orale Orale Inc
# Restaurant not found... skipping.
# processing record 85, CHATZ
# Restaurant not found... skipping.
# processing record 86, Caffe Ambrosia
# Restaurant not found... skipping.
# processing record 87, Calzone's
# processing record 88, Bohemian Cigar Store
# processing record 89, Vieni-Vieni
# Restaurant not found... skipping.
# processing record 90, North Beach Restaurant
# processing record 91, Hawaii West
# Restaurant not found... skipping.
# processing record 92, My Canh Restaurant
# processing record 93, The Stinking Rose
# processing record 94, Yuet Lee Restaurant
# processing record 95, Garden of Eden
# Restaurant not found... skipping.
# processing record 96, Sam's Pizza
# processing record 97, Franchino
# processing record 98, Caffe Greco
# processing record 99, Mara's
# processing record 100, Il Pollaio
# processing record 101, Ristorante Ideale
# processing record 102, Mo's Grill
# processing record 103, Maykadeh Restaurant
# processing record 104, Columbus Cafe
# processing record 105, Silverhat Bar, Inc
# Restaurant not found... skipping.
# processing record 106, Tommaso
# processing record 107, The House
# processing record 108, Dol-Ho Restaurant
# processing record 109, San Francisco Athletic Club
# Restaurant not found... skipping.
# processing record 110, Caffe Trieste
# processing record 111, Roxanne Cafe
# processing record 112, COURTYARD BY MARRIOTT-COFFEE SHOP
# Restaurant not found... skipping.
# processing record 113, Quickly
# processing record 114, Viking's Giant Sub
# processing record 115, Cafe Bakery
# processing record 116, Donut Time
# Restaurant not found... skipping.
# processing record 117, SHERATON PALACE - EMP.  CAFETERIA
# Restaurant not found... skipping.
# processing record 118, Daily Health
# Restaurant not found... skipping.
# processing record 119, Boudin Sourdough Bakery
# Restaurant not found... skipping.
# processing record 120, Nizario's Pizza
# processing record 121, Marnee Thai Restaurant
# processing record 122, EL SALVADOR RESTAURANT
# processing record 123, Hamburger Haven
# processing record 124, THAI TIME RESTAURANT
# Restaurant not found... skipping.
# processing record 125, LITTLE HENRY'S
# processing record 126, Gordo Taqueria #1
# processing record 127, Loi's Vietnamese Restaurant
# processing record 128, KATIA'S
# Restaurant not found... skipping.
# processing record 129, DESTINO RESTAURANT
# processing record 130, TACO LOS ALTOS
# processing record 131, NEW TSING TAO RESTAURANT
# processing record 132, BURRITO EXPRESS
# processing record 133, WON TON HOUSE
# processing record 134, YOU SEE SUSHI
# processing record 135, TSING TAO RESTAURANT
# Restaurant not found... skipping.
# processing record 136, J & A RESTAURANT
# processing record 137, A-1 BAKERY
# Restaurant not found... skipping.
# processing record 138, CALIFORNIA TENNIS CLUB
# Restaurant not found... skipping.
# processing record 139, EL BURRITO EXPRESS #2
# processing record 140, SUBWAY SANDWICHES & SALADS
# processing record 141, Swan Oyster Depot
# processing record 142, ANDERSEN BAKERY
# processing record 143, TAN-TAN
# Restaurant not found... skipping.
# processing record 144, BRAZEN HEAD RESTAURANT
# processing record 145, VIKINGS GIANT SUBMARINE SANDWICHES
# processing record 146, MARINA SUBMARINE
# processing record 147, THEM KY RESTAURANT
# processing record 148, MONG THU COFFEE SHOP
# processing record 149, BEN WAH RESTAURANT
# processing record 150, MOZZARELLA DI BUFALA PIZZERIA II
# processing record 151, Cafe Bellini
# Restaurant not found... skipping.
# processing record 152, Educated Palate
# processing record 153, BAKERY/ICE CREAM/STOREROOM
# Restaurant not found... skipping.
# processing record 154, MOSHI MOSHI
# processing record 155, MARIPOSA HUNTERS POINT YACHT CLUB
# Restaurant not found... skipping.
# processing record 156, BAY VIEW BOAT CLUB
# Restaurant not found... skipping.
# processing record 157, MONTE CRISTO SOCIAL CLUB
# Restaurant not found... skipping.
# processing record 158, Piperade
# processing record 159, Boudin Bakery
# processing record 160, Ben & Jerry's
# Restaurant not found... skipping.
# processing record 161, Sushi Rapture
# processing record 162, Courtyard by Marriott at Fisherman's Wharf
# Restaurant not found... skipping.
# processing record 163, EDEN PLAZA CAFE
# Restaurant not found... skipping.
# processing record 164, B & J QUARTER POUNDER BURGERS
# Restaurant not found... skipping.
# processing record 165, BABY'S EATERY AND PALABOK
# processing record 166, ANGELINA'S DELI-CAFE & CATERING
# Restaurant not found... skipping.
# processing record 167, TAQUERIA EL FAROLITO NO. 2
# processing record 168, LOS PLANES DE RENDEROS
# processing record 169, Kam Po Kitchen
# processing record 170, Molinari Delicatessen
# processing record 171, Cafe Jacqueline
# processing record 172, Golden Boy Pizza
# processing record 173, New Hollywood Bakery & Restaurant
# processing record 174, Firenze By Night
# processing record 175, DELFINA RESTAURANT
# processing record 176, Pancho's Salsa Bar & Grill
# processing record 177, PATPONG THAI CUISINE, INC.
# Restaurant not found... skipping.
# processing record 178, House of Nanking
# processing record 179, Le Petit Cafe
# processing record 180, Lucky Creation Vegetarian Restaurant LLC
# Restaurant not found... skipping.
# processing record 181, Happy Donuts
# processing record 182, MARCELLO'S PIZZA
# processing record 183, Sabra Restaurant
# processing record 184, Working Girls' Cafe'
# processing record 185, Cafe Dolci
# processing record 186, Town & Country Club
# Restaurant not found... skipping.
# processing record 187, Ritz-Carlton, SF -  P-37 Restaurant and Bar
# processing record 188, Ritz-Carlton SF - Club Lounge
# processing record 189, Cafe Ethiopia
# processing record 190, PEKING WOK RESTAURANT
# processing record 191, TWO JACKS SEAFOOD #2
# processing record 192, EL CASTILLITO TAQUERIA INC.
# Restaurant not found... skipping.
# processing record 193, BUFFALO BURGERS RESTAURANT
# processing record 194, IRVING PIZZA
# processing record 195, KENTUCKY FRIED CHICKEN #50
# Restaurant not found... skipping.
# processing record 196, SHANGRILA VEGETARIAN REST
# Restaurant not found... skipping.
# processing record 197, JAVA BEACH CAFE
# processing record 198, MING TAI WUN TUN NOODLE, INC.
# Restaurant not found... skipping.
# processing record 199, VANIDA THAI KITCHEN
# processing record 200, The Sunset's Best Seafood Restaurant
# processing record 201, RAILROAD EXPRESSO CAFE
# Restaurant not found... skipping.
# processing record 202, SERRANO'S PIZZA II
# Restaurant not found... skipping.
# processing record 203, HEUNG YUEN RESTAURANT
# processing record 204, BIG MOUTH BURGERS
# processing record 205, RINCON PERUANO RESTAURANT
# processing record 206, CHAVITA'S MEXICAN RESTAURANT
# processing record 207, VALENCIA PIZZA & PASTA
# processing record 208, PETES BARBEQUE
# processing record 209, LA SANTANECA DE LA MISSION
# processing record 210, PHUKET THAI RESTAURANT
# processing record 211, IL BORGO
# processing record 212, ALAMO SQUARE
# Restaurant not found... skipping.
# processing record 213, LOVE 'N HAIGHT COFFEE & DELI
# processing record 214, CENTRAL COFFEE TEA & SPICE
# processing record 215, PORK STORE CAFE
# processing record 216, UNIVERSAL CAFE
# processing record 217, SANDWICH PLACE, THE
# processing record 218, ARINELL PIZZA
# processing record 219, STARBUCKS COFFEE #9219
# Restaurant not found... skipping.
# processing record 220, Tricolore Caffe' and Pizzeria
# processing record 221, STARBUCKS COFFEE
# Restaurant not found... skipping.
# processing record 222, SUBWAY 16604
# processing record 223, STARBUCKS COFFEE #531
# Restaurant not found... skipping.
# processing record 224, SQUAT & GOBBLE CAFE #3
# processing record 225, Peet's Coffee & Tea, Inc
# Restaurant not found... skipping.
# processing record 226, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 227, Tony's Cable Car Restaurant
# processing record 228, MINI CAFE
# processing record 229, Star Bagels
# Restaurant not found... skipping.
# processing record 230, Aux Delices Vietnam
# processing record 231, UA Twin Stonestown
# Restaurant not found... skipping.
# processing record 232, SUNFLOWER RESTAURANT
# processing record 233, Boudin Petit Cafe
# processing record 234, Zona Rosa
# processing record 235, OKINA SUSHI
# processing record 236, TEKKA JAPANESE RESTAURANT
# processing record 237, PEET'S COFFEES & TEAS
# Restaurant not found... skipping.
# processing record 238, SWEET THINGS
# Restaurant not found... skipping.
# processing record 239, PANCHO'S
# processing record 240, TAWAN'S THAI FOOD
# processing record 241, ROYAL GROUND COFFEE
# Restaurant not found... skipping.
# processing record 242, PAZZO
# processing record 243, Yamo Restaurant
# processing record 244, Sunflower Cafe
# processing record 245, Banwich
# processing record 246, JAVA SUPREME
# processing record 247, KABABAYAN FAST FOOD
# processing record 248, REVERIE COFFEE CAFE
# processing record 249, NORTH BEACH PIZZA
# processing record 250, LAVA JAVA
# processing record 251, STARBUCKS COFFEE CO.
# processing record 252, STARBUCKS
# Restaurant not found... skipping.
# processing record 253, MORNING DUE
# processing record 254, AMASIA HIDE'S SUSHI BAR
# processing record 255, ORPHAN ANDY'S
# processing record 256, ANCHOR OYSTER BAR INC.
# Restaurant not found... skipping.
# processing record 257, TAQUERIA EL BUEN SABOR
# processing record 258, WE BE SUSHI
# processing record 259, RAIN TREE CAFE
# processing record 260, GORDO TAQUERIA #6
# processing record 261, LA MEDITERRANEE I, INC.
# Restaurant not found... skipping.
# processing record 262, THE BLACK HORSE LONDON DELI
# Restaurant not found... skipping.
# processing record 263, CHLOE'S
# processing record 264, Sabor De San Miguel
# processing record 265, HIGHER GROUNDS
# processing record 266, SPIKE'S COFFEES & TEAS
# Restaurant not found... skipping.
# processing record 267, The Beanery Inc
# Restaurant not found... skipping.
# processing record 268, Cordon Bleu
# processing record 269, CREPES ON COLE
# processing record 270, KING OF THAI NOODLE HOUSE
# processing record 271, EXIT THEATRE
# Restaurant not found... skipping.
# processing record 272, LA TORTILLA
# processing record 273, SUSHI TIME
# processing record 274, STARBUCKS COFFEE CO.
# Restaurant not found... skipping.
# processing record 275, RESTAURANTE FAMILIAR
# processing record 276, CAFE LA TAZA
# processing record 277, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 278, PEBBLE'S CAFE
# processing record 279, GASPARE'S PIZZA HOUSE AND RESTAURANT
# processing record 280, YUMMA'S MED GRILL
# processing record 281, La Copa Loca
# Restaurant not found... skipping.
# processing record 282, STARBUCKS
# Restaurant not found... skipping.
# processing record 283, SWEET DELIGHT BAKERY
# processing record 284, HOLEY BAGEL BAKERY
# Restaurant not found... skipping.
# processing record 285, Waterfront Bakery
# Restaurant not found... skipping.
# processing record 286, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 287, CAFE V
# processing record 288, KISS SEAFOOD
# processing record 289, Whole Foods Steep Brew
# Restaurant not found... skipping.
# processing record 290, Holiday Inn Express-Main Kitchen
# Restaurant not found... skipping.
# processing record 291, A2 CAFE
# Restaurant not found... skipping.
# processing record 292, STARBUCKS COFFEE
# processing record 293, PEET'S COFFEE & TEA
# processing record 294, Peet's Coffee & Tea
# processing record 295, FOUR SEASONS HOTEL- EMPLOYEE  CAFETERIA
# Restaurant not found... skipping.
# processing record 296, Starbucks Coffee Company #6765
# Restaurant not found... skipping.
# processing record 297, Nonna Rose Restaurant
# Restaurant not found... skipping.
# processing record 298, CLUB WAZIEMA
# processing record 299, STARBUCKS #5852
# Restaurant not found... skipping.
# processing record 300, CHOUQUET'S
# processing record 301, CITY'S CHOICE
# Restaurant not found... skipping.
# processing record 302, STARBUCKS
# Restaurant not found... skipping.
# processing record 303, Neiman Marcus On The Square
# processing record 304, Cafe Niebaum Coppola
# processing record 305, I LUV TERIYAKI AND SUSHI
# processing record 306, OMNI S.F. Hotel - Food & Beverage Storeroom
# Restaurant not found... skipping.
# processing record 307, Fino
# Restaurant not found... skipping.
# processing record 308, Cornell Hotel - Jeanne D'Arc
# processing record 309, Uncle Vito's Pizza
# processing record 310, Asia Chinese Food #2
# processing record 311, TANPOPO
# processing record 312, 901 Columbus Cafe
# processing record 313, SF Bay Club - Court Cafe
# Restaurant not found... skipping.
# processing record 314, Nick's Lighthouse
# Restaurant not found... skipping.
# processing record 315, Caffe Bianco
# processing record 316, ESPERPENTO RESTAURANT
# processing record 317, Young's Restaurant
# processing record 318, Zazie
# processing record 319, BURGERMEISTER
# processing record 320, Cafe Bean
# processing record 321, CLADDAGH COFFEE
# Restaurant not found... skipping.
# processing record 322, Tung Sing Restaurant
# processing record 323, STARBUCKS COFFEE #5646
# Restaurant not found... skipping.
# processing record 324, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 325, CLEMENT BBQ RESTAURANT
# processing record 326, BENDERS BAR & GRILL
# processing record 327, LUPA TRATTORIA
# processing record 328, Casa Mexicana Restaurant
# processing record 329, SWEET CHINITO
# processing record 330, KEZAR PUB
# processing record 331, AXUM
# processing record 332, MARTHA & BROS. COFFEE CO
# processing record 333, COURTYARD BY MARRIOTT-RESTAURANT
# Restaurant not found... skipping.
# processing record 334, STARBUCKS
# Restaurant not found... skipping.
# processing record 335, PANDA EXPRESS
# processing record 336, SILVER CREST DONUT SHOP
# processing record 337, Just For You Cafe Inc.
# Restaurant not found... skipping.
# processing record 338, WORKING GIRLS' CAFE III
# processing record 339, RUBIN'S
# Restaurant not found... skipping.
# processing record 340, NORDSTROM BAZILLE
# Restaurant not found... skipping.
# processing record 341, New Lun Ting Cafe, Inc
# Restaurant not found... skipping.
# processing record 342, Sai's Vietnamese Restaurant
# processing record 343, Plouf
# processing record 344, TWILIGHT CAFE
# processing record 345, Raintree Cafe
# processing record 346, EL TOREADOR FONDA MEXICANA RESTAURANT
# Restaurant not found... skipping.
# processing record 347, Lanna Restaurant
# processing record 348, Emporio Rulli Il Caffe at Union Square
# Restaurant not found... skipping.
# processing record 349, SEA BREEZE CAFE
# processing record 350, CAFE MUMS
# processing record 351, KFC/TACO BELL
# processing record 352, Sun Rise Restaurant
# processing record 353, SAI JAI THAI
# processing record 354, Osha Thai Noodle Cafe
# processing record 355, McAllister Grocery & Deli
# Restaurant not found... skipping.
# processing record 356, Fisherman's Pizzeria Inc [#50]
# Restaurant not found... skipping.
# processing record 357, Dar Bar Pakistani/Indian Cusine
# Restaurant not found... skipping.
# processing record 358, FLORIO
# processing record 359, Subway Sandwiches
# processing record 360, Academy Bar & Kitchen
# processing record 361, Capannina
# processing record 362, EXECUTIVE CAFE
# processing record 363, GARDEN HOUSE CAFE
# processing record 364, ATLAS CAFE
# processing record 365, PHILIPPINE DELICACIES
# Restaurant not found... skipping.
# processing record 366, TIO CHILOS GRILL
# processing record 367, CHEVRON #1512
# Restaurant not found... skipping.
# processing record 368, BRAVO PIZZA
# processing record 369, MOONLIGHT CAFE
# processing record 370, Cesario
# processing record 371, Banquet Kitchen
# Restaurant not found... skipping.
# processing record 372, Nob Hill Cafe
# processing record 373, Sushi on North Beach
# processing record 374, B44
# processing record 375, Murphy's
# processing record 376, Cafe Bastille
# processing record 377, Ma's Dim Sum & Cafe
# processing record 378, 15 Romolo
# processing record 379, Battery Street Coffee Roastery
# processing record 380, Pat's Cafe
# processing record 381, Cafe Venue
# processing record 382, Diller's Delicatessen
# processing record 383, Escape From New York Pizza
# processing record 384, Cafe Tiramisu
# processing record 385, Pasquales
# processing record 386, MAI'S VIETNAMESE RESTAURANT
# processing record 387, SIMPLE PLEASURES CAFE
# processing record 388, Cafe Bakery
# processing record 389, TARAVAL OKAZU YA
# processing record 390, All stars Donuts
# processing record 391, LINCOLN PARK BAR AND GRILL
# Restaurant not found... skipping.
# processing record 392, STARBUCKS COFFEE
# Restaurant not found... skipping.
# processing record 393, Sunrise Deli
# processing record 394, YUMMY YUMMY VIETNAMESE RESTAURANT
# processing record 395, Five Happiness
# processing record 396, STARBUCKS COFFEE CO. #603
# Restaurant not found... skipping.
# processing record 397, PLUTO'S
# processing record 398, BULLSHEAD RESTAURANT
# processing record 399, Han Bat Korean Restaurant
# processing record 400, T C PASTRY
# processing record 401, EBISU RESTAURANT
# processing record 402, Spiazzo
# processing record 403, AL-MASRI EGYPTIAN RESTAURANT
# processing record 404, MICADO  RESTAURANT
# processing record 405, KENTUCKY FRIED CHICKEN
# processing record 406, MY FAVORITE CAFE
# processing record 407, BURMA SUPERSTAR RESTAURANT
# processing record 408, GOLDEN CHARIOT BAKERY & REST
# processing record 409, Four Star Theatre - Snack Bar
# Restaurant not found... skipping.
# processing record 410, PRESIDIO GOLF CLUB
# Restaurant not found... skipping.
# processing record 411, SRI THAI CUISINE
# processing record 412, GENEVA STEAK HOUSE
# processing record 413, EL POLLO SUPREMO
# processing record 414, PANDA EXPRESS
# processing record 415, Elaine's Kitchen
# processing record 416, Hook a Cook
# Restaurant not found... skipping.
# processing record 417, EXTREME  PIZZA
# processing record 418, THE GROVE FILLMORE
# processing record 419, MONROE RESIDENCE CLUB
# Restaurant not found... skipping.
# processing record 420, KENMORE RESIDENCE CLUB
# Restaurant not found... skipping.
# processing record 421, QUEEN ANNE HOTEL
# Restaurant not found... skipping.
# processing record 422, VIA VENETO
# processing record 423, Joanie's Diner Inc.
# Restaurant not found... skipping.
# processing record 424, Hyde Street Seafood House & Raw Bar, Inc
# Restaurant not found... skipping.
# processing record 425, Cocotte
# processing record 426, ZA
# processing record 427, Amarena
# processing record 428, ATAMI SUSHI BAR & GRILL
# processing record 429, ZUSHI-PUZZLE
# processing record 430, Thai Spice Restaurant
# processing record 431, Street Restaurant
# processing record 432, Starbucks Coffee Company
# Restaurant not found... skipping.
# processing record 433, Peet's Coffee & Tea
# Restaurant not found... skipping.
# processing record 434, KENTUCKY FRIED CHICKEN #249
# Restaurant not found... skipping.
# processing record 435, CARL'S JUNIOR
# processing record 436, Olympic Flame Cafe
# processing record 437, Original Perfect Hamburger
# processing record 438, Kim Thanh Restaurant
# processing record 439, ANH HONG PHU-NHUAN RESTAURANT
# Restaurant not found... skipping.
# processing record 440, A La Turca
# processing record 441, Sakana
# processing record 442, RUTH'S CHRIS STEAK HOUSE
# processing record 443, NOAH'S BAGELS
# Restaurant not found... skipping.
# processing record 444, DRAGON WELL
# processing record 445, B & M MEI SING RESTAURANT
# Restaurant not found... skipping.
# processing record 446, CHIEFTAIN IRISH PUB, THE
# processing record 447, HOWARD STREET COFFEE ROASTERY CAFE
# Restaurant not found... skipping.
# processing record 448, STARBUCKS COFFEE CO.
# Restaurant not found... skipping.
# processing record 449, THE BITTER END
# processing record 450, SHERA.-PAL.HOTEL MAXFIELD'S GRILL
# Restaurant not found... skipping.
# processing record 451, FRINGALE
# processing record 452, HARD KNOX CAFE
# processing record 453, GOAT HILL PIZZA
# processing record 454, Cafe Francisco
# processing record 455, Mamas on Washington Square
# processing record 456, Acquerello
# processing record 457, PRINCESS BAKERY
# Restaurant not found... skipping.
# processing record 458, Starbucks Coffee Co
# Restaurant not found... skipping.
# processing record 459, Garden Bakery
# Restaurant not found... skipping.
# processing record 460, Palio Paninoteca
# Restaurant not found... skipping.
# processing record 461, Tokyo Express
# processing record 462, The AA Bakery & Cafe
# processing record 463, Kam Lok Restaurant
# processing record 464, Le Regency
# processing record 465, Cafe Claude
# processing record 466, Starbucks Coffee Company
# Restaurant not found... skipping.
# processing record 467, Starbucks Coffee Co
# Restaurant not found... skipping.
# processing record 468, Ramzi's Cafe
# processing record 469, Niji Japanese Grille
# processing record 470, BLUE DANUBE COFFEE HOUSE
# Restaurant not found... skipping.
# processing record 471, Ritz-Carlton SF - Employee Cafeteria
# processing record 472, Ritz-Carlton SF - Banquet Kitchen
# processing record 473, TAIWAN RESTAURANT
# processing record 474, ALI BABA'S CAVE RESTAURANT
# processing record 475, LA MEDITERRANEE
# processing record 476, Golden Donuts
# processing record 477, SAKANA BUNE RESTAURANT
# processing record 478, ORIENTAL SEAFOOD RESTAURANT
# processing record 479, GOLD MIRROR ITALIAN RESTAURANT
# processing record 480, STARBUCKS COFFEE
# Restaurant not found... skipping.
# processing record 481, TIA MARGARITA INC
# Restaurant not found... skipping.
# processing record 482, TAQUERIA CAN-CUN
# processing record 483, BURGER JOINT
# processing record 484, Garcon
# processing record 485, BLUE FRONT DELI
# processing record 486, THE CITRUS CLUB
# processing record 487, IRMA'S PAMPANGA RESTAURANT
# processing record 488, JADE CAFE #3
# processing record 489, LA PAZ RESTAURANT
# processing record 490, Velvet Cantina
# processing record 491, Ristorante Ti Piacera
# processing record 492, EL TACO LOCO INC.
# Restaurant not found... skipping.
# processing record 493, GRAND MISSION DONUT & BAKERY
# Restaurant not found... skipping.
# processing record 494, LAS TINAJAS
# processing record 495, SMILE'S  B.B.Q.
# processing record 496, TAQUERIA EL FAROLITO
# processing record 497, CHINA EXPRESS
# processing record 498, TAQUERIA SAN JOSE #1
# processing record 499, LA TRAVIATA
# processing record 500, LA TAQUERIA
# processing record 501, CLOONEY'S
# Restaurant not found... skipping.
# processing record 502, BEAN BAG COFFEE HOUSE
# processing record 503, TWO JACKS SEAFOOD
# processing record 504, CAFE INTERNATIONAL
# processing record 505, PLOY #2 THAI CUISINE
# processing record 506, Mission Hunan Restaurant
# processing record 507, MANIVANH THAI RESTAURANT
# processing record 508, TAQUERIA SAN FRANCISCO
# Restaurant not found... skipping.
# processing record 509, ST FRANCIS FOUNTAIN
# processing record 510, BOOGALOOS
# processing record 511, TAQUERIA EL FAROLITO #3
# processing record 512, LA GALLINITA
# processing record 513, PUERTO ALEGRE NO. 2
# processing record 514, MANORA'S THAI CUISINE
# processing record 515, NEW CASTILLITO INC.
# Restaurant not found... skipping.
# processing record 516, San Jalisco
# processing record 517, MUDDY WATERS
# Restaurant not found... skipping.
# processing record 518, Okoze Sushi
# processing record 519, Starbucks
# Restaurant not found... skipping.
# processing record 520, CAFE UNION
# processing record 521, STARBUCK'S COFFEE #525
# Restaurant not found... skipping.
# processing record 522, PLUTO'S
# processing record 523, Posh Bagel
# Restaurant not found... skipping.
# processing record 524, AMERICANA GRILL & FOUNTAIN
# processing record 525, ALEGRIAS
# processing record 526, PACIFIC PLAZA CAFE
# processing record 527, VENICE PIZZA AND RESTAURANT
# processing record 528, PEET'S COFFEE & TEA
# Restaurant not found... skipping.
# processing record 529, KATES KITCHEN
# processing record 530, PETER D'S RESTAURANT
# processing record 531, EMPEROR PALACE RESTAURANT
# processing record 532, NOAH'S NEW YORK BAGELS #2120
# Restaurant not found... skipping.
# processing record 533, Its Tops Coffee Shop
# processing record 534, EXTREME PIZZA
# processing record 535, HAI'S RESTAURANT
# processing record 536, ANANDA FUARA
# processing record 537, Starbucks Coffee Co
# Restaurant not found... skipping.
# processing record 538, CAFE MARS
# processing record 539, Dojima-Ann
# processing record 540, BELLA TRATTORIA
# processing record 541, LA VIE VIETNAMESE REST
# processing record 542, HONG KONG RESTAURANT
# processing record 543, Last Drop Tavern
# Restaurant not found... skipping.
# processing record 544, Pride of the Mediterranean
# processing record 545, CAFE LA BOHEME
# Restaurant not found... skipping.
# processing record 546, Thai Chef 2
# processing record 547, KEZAR BAR & RESTAURANT
# processing record 548, Bambino's Ristorante
# processing record 549, WING HING RESTAURANT
# processing record 550, BURGERMEISTER
# processing record 551, MARTHA & BROS COFFEE CO
# Restaurant not found... skipping.
# processing record 552, SF BAGEL CO. (KATZ BAGELS)
# Restaurant not found... skipping.
# processing record 553, THE PHOENIX BAR & RESTAURANT
# processing record 554, BALOMPIE CAFE
# processing record 555, WAN KEE RESTAURANT
# processing record 556, HUNAN CHEF
# processing record 557, Alice's Restaurant
# processing record 558, ARIAKE
# processing record 559, FIREFLY
# processing record 560, ERIC'S RESTAURANT
# processing record 561, THE BLUE PLATE
# processing record 562, LOS PANCHOS
# processing record 563, TYGER'S
# processing record 564, HOWARD'S CAFE
# processing record 565, MELS DRIVE IN
# processing record 566, RED A BAKERY
# processing record 567, GOURMET DIM SUM & CAFE
# processing record 568, Red Jade Restaurant
# processing record 569, HUNAN EMPIRE
# processing record 570, BOBOQUIVARI'S
# processing record 571, Main Kitchen-Mission Grille
# processing record 572, New Mangia Tutti Ristorante
# processing record 573, CAFFE' ROMA
# processing record 574, ROSE'S CAFE
# processing record 575, NOAH'S NEW YORK BAGELS #2147
# Restaurant not found... skipping.
# processing record 576, TAQUERIA CANCUN
# processing record 577, HAMANO SUSHI
# processing record 578, SOCIALE
# processing record 579, STARBUCKS
# Restaurant not found... skipping.
# processing record 580, OSTERIA
# processing record 581, CASA MEXICANA
# processing record 582, AL-HAMRA
# processing record 583, TAQUERIA GUADALAJARA
# processing record 584, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 585, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 586, LEE'S DELI
# processing record 587, G & L RESTAURANT
# processing record 588, Sushi Hunter
# processing record 589, MELS DRIVE-IN
# processing record 590, MONGKOK DIM SUM & RESTAURANT
# processing record 591, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 592, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 593, Grandeho's Kamekyo II
# Restaurant not found... skipping.
# processing record 594, NEW EMMY'S RESTAURANT
# processing record 595, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 596, STARBUCKS COFFEE #5486
# Restaurant not found... skipping.
# processing record 597, Grand Hyatt - Bistro-Employee Cafeteria
# Restaurant not found... skipping.
# processing record 598, Pena Pachamama
# processing record 599, EAGLE PIZZA
# processing record 600, Hard Rock Cafe
# processing record 601, KITARO JAPANESE RESTAURANT
# processing record 602, THE OLYMPIC CLUB AT LAKESIDE
# Restaurant not found... skipping.
# processing record 603, THE OLYMPIC CLUB AT LAKESIDE, UPPER
# Restaurant not found... skipping.
# processing record 604, SEASONS RESTAURANT
# processing record 605, San Raku Restaurant
# processing record 606, Kells
# processing record 607, SANRAKU
# processing record 608, Kokkari
# processing record 609, Jasper's Corner Tap & Kitchen
# processing record 610, HAYSTACK PIZZA RESTAURANT
# processing record 611, ELIZA'S RESTAURANT
# processing record 612, Holiday Inn ExpressHotel - Pantry Kitchen
# Restaurant not found... skipping.
# processing record 613, Fountain Cafe
# processing record 614, STARBUCK'S COFFEE #6605
# Restaurant not found... skipping.
# processing record 615, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 616, MOMO'S
# processing record 617, FOREIGN CINEMA
# processing record 618, The Cheesecake Factory
# processing record 619, Public House/Mijita
# Restaurant not found... skipping.
# processing record 620, Bon Appetit @ USF-Market Cafe
# Restaurant not found... skipping.
# processing record 621, OMNI S.F. Hotel - Main Kitchen
# Restaurant not found... skipping.
# processing record 622, OMNI S.F. Hotel - Restaurant & Bar
# Restaurant not found... skipping.
# processing record 623, Academy of Arts Univ- I House Cafe
# Restaurant not found... skipping.
# processing record 624, The White Horse
# processing record 625, Leatherneck Steakhouse - Marines' Memorial Assn
# Restaurant not found... skipping.
# processing record 626, Marines Memorial Club - Banquet
# Restaurant not found... skipping.
# processing record 627, Luques Restaurant & Bar
# processing record 628, Elks Club
# Restaurant not found... skipping.
# processing record 629, Academy of Arts University
# Restaurant not found... skipping.
# processing record 630, Castagnola's Restaurant
# processing record 631, Lou's Fish Shack
# processing record 632, Harrington's Bar & Grill
# processing record 633, Whole Foods Market
# Restaurant not found... skipping.
# processing record 634, New Sun Hong Kong Restaurant
# processing record 635, Safeway Store #4601
# Restaurant not found... skipping.
# processing record 636, GOLDEN STATE ADULT DAY HEALTH CARE
# Restaurant not found... skipping.
# processing record 637, Good Earth Cafe
# processing record 638, ST MARY'S HOSPITAL CAFETERIA
# Restaurant not found... skipping.
# processing record 639, PORTICO
# Restaurant not found... skipping.
# processing record 640, KOH SAMUI & THE MONKEY
# processing record 641, LEAPING LEMUR CAFE
# processing record 642, JAY N BEE CLUB
# processing record 643, PUERTO ALEGRE
# processing record 644, The Penthouse Club & Steakhouse
# Restaurant not found... skipping.
# processing record 645, PALOMINO EURO-BISTRO
# Restaurant not found... skipping.
# processing record 646, Local Roots Leidesdorff
# Restaurant not found... skipping.
# processing record 647, Far East Cafe
# processing record 648, R & G Executive Lounge, Inc
# Restaurant not found... skipping.
# processing record 649, Tad's
# processing record 650, PEKING RESTAURANT
# processing record 651, TENNESSEE GRILL INC
# Restaurant not found... skipping.
# processing record 652, Victor's Pizza
# processing record 653, CHIPOTLE MEXICAN GRILL
# processing record 654, TURK & LARKIN DELI
# Restaurant not found... skipping.
# processing record 655, ST. FRANCIS YACHT CLUB
# Restaurant not found... skipping.
# processing record 656, Mollie Stone's Grand Central Market
# Restaurant not found... skipping.
# processing record 657, Crustacean
# processing record 658, Benkyodo Co
# Restaurant not found... skipping.
# processing record 659, Harris' Restaurant
# processing record 660, McCormick & Kuleto's Seafood Restaunt
# Restaurant not found... skipping.
# processing record 661, SAFEWAY STORES, INC. #995
# Restaurant not found... skipping.
# processing record 662, Cafe Mason
# processing record 663, Ghirardelli Chcocolate Company
# Restaurant not found... skipping.
# processing record 664, CHA-AM RESTAURANT
# processing record 665, FLOWER MARKET CAFE
# processing record 666, HOTEL UTAH SALOON, THE
# Restaurant not found... skipping.
# processing record 667, DELANCEY ST. RESTAURANT
# processing record 668, Limon Restaurant
# processing record 669, ONE MARKET RESTAURANT
# processing record 670, ITALIAN AMERICAN SOCIAL CLUB
# processing record 671, YANK SING RESTAURANT
# processing record 672, Employee Cafeteria
# Restaurant not found... skipping.
# processing record 673, TOWN'S END RESTAURANT & BAKERY
# processing record 674, The Family
# processing record 675, Lori's Diner
# processing record 676, Franciscan Crab Restaurant
# processing record 677, Yee's Restaurant
# processing record 678, Hyatt Union Square Main Kitchen
# processing record 679, Cioppino's
# processing record 680, Le Central Bistro Corp
# Restaurant not found... skipping.
# processing record 681, Tadich Grill
# processing record 682, Francisca Club
# Restaurant not found... skipping.
# processing record 683, Brandy Ho's Hunan Food
# processing record 684, Lee's Deli
# processing record 685, New Asia Restaurant
# processing record 686, The Royal Exchange Restaurant Co.
# processing record 687, Pier 2620 Hotel Fisherman's Wharf
# Restaurant not found... skipping.
# processing record 688, HAN IL KWAN
# processing record 689, MING'S DINER
# processing record 690, NEW ERITREA RESTAURANT
# processing record 691, PIRRO'S PIZZERIA
# processing record 692, Schuberts Bakery
# Restaurant not found... skipping.
# processing record 693, MOSCOW & TBILSI BAKERY STORE
# Restaurant not found... skipping.
# processing record 694, NORIEGA TERIYAKI HOUSE
# processing record 695, United Irish Cultural Center
# processing record 696, YANK SING
# processing record 697, PPQ Vietnamese RESTAURANT
# processing record 698, Farallon Restaurant
# processing record 699, International House of Pancakes
# processing record 700, PHO HUYNH HIEP II
# processing record 701, MARNEE THAI RESTAURANT
# processing record 702, GIORGIO'S PIZZA
# processing record 703, PASQUALES
# processing record 704, MEL'S DRIVE-IN
# processing record 705, THANH LONG RESTAURANT
# processing record 706, TOMMYS MEXICAN RESTAURANT
# processing record 707, LAM HOA THUAN RESTAURANT
# processing record 708, SHENG KEE BAKERY
# Restaurant not found... skipping.
# processing record 709, ST. ANNE'S HOME
# Restaurant not found... skipping.
# processing record 710, LITTLE JOES PIZZA REST.
# processing record 711, S F GOLF CLUB
# Restaurant not found... skipping.
# processing record 712, Connection, The
# Restaurant not found... skipping.
# processing record 713, KENTUCKY FRIED CHICKEN
# processing record 714, VILLA D'ESTE
# processing record 715, Croatian Cultural Center
# Restaurant not found... skipping.
# processing record 716, The Olive Garden Italian
# Restaurant not found... skipping.
# processing record 717, Cigar Bar and Grill
# processing record 718, HARRY'S BAR
# processing record 719, Wing Lum Cafe
# processing record 720, Super Burrito
# processing record 721, Granada Hotel Dining Room
# Restaurant not found... skipping.
# processing record 722, Broadmoor, The
# Restaurant not found... skipping.
# processing record 723, RUSSIAN CENTER SOCIAL HALL
# Restaurant not found... skipping.
# processing record 724, Round Table Pizza
# processing record 725, ALBORZ
# processing record 726, Pane e Vino Trattoria
# processing record 727, Swensen's of SF Inc
# Restaurant not found... skipping.
# processing record 728, Buena Vista Cafe
# processing record 729, Jacks Cannery
# Restaurant not found... skipping.
# processing record 730, Gary Danko
# processing record 731, HARVEY'S
# processing record 732, The Bell
# processing record 733, The Real Food Company
# Restaurant not found... skipping.
# processing record 734, La Folie
# processing record 735, PERRYS
# processing record 736, BAR NONE-SF, LLC
# Restaurant not found... skipping.
# processing record 737, House of Prime Rib
# processing record 738, New Delhi Restaurant
# processing record 739, Daily Grill
# processing record 740, FAMILY BILLIARDS
# Restaurant not found... skipping.
# processing record 741, DON RAMON
# processing record 742, The Keystone
# Restaurant not found... skipping.
# processing record 743, 21ST AMENDMENT BREWERY CAFE
# Restaurant not found... skipping.
# processing record 744, Farallon
# processing record 745, GARDEN CT. RESTAURANT & BAR
# Restaurant not found... skipping.
# processing record 746, OZUMO
# processing record 747, TASTE CATERING
# processing record 748, MCDONALD'S #7413
# Restaurant not found... skipping.
# processing record 749, CAFE PHOENIX
# processing record 750, Levi Strauss & Co
# Restaurant not found... skipping.
# processing record 751, Safeway Stores, Inc. #1206
# Restaurant not found... skipping.
# processing record 752, Bimbo's 365 Club
# Restaurant not found... skipping.
# processing record 753, Alioto's
# Restaurant not found... skipping.
# processing record 754, Fog Harbor Fish House
# processing record 755, Wipe Out Bar & Grill
# processing record 756, Hornblower Hospitality Svcs/MV Calif. Hornblower
# Restaurant not found... skipping.
# processing record 757, Crab House
# processing record 758, The Pier Market
# processing record 759, Swiss Louis Restaurant
# Restaurant not found... skipping.
# processing record 760, Scoma's Restaurant
# processing record 761, CANTON DIM SUM HOUSE, INC.
# processing record 762, Raven Bar
# Restaurant not found... skipping.
# processing record 763, BASIL THAI RESTAURANT & BAR
# processing record 764, GRAND LODGE OF CALIFORNIA
# Restaurant not found... skipping.
# processing record 765, CHOW
# processing record 766, ROUND TABLE PIZZA
# processing record 767, Trattoria Contadina Restaurant
# processing record 768, Sears Fine Food
# processing record 769, BOULEVARD
# processing record 770, THE BEACH CHALET BREWERY & REST.
# processing record 771, Morton's Chicago Steakhouse
# processing record 772, Borodudur Restaurant
# processing record 773, University Club
# Restaurant not found... skipping.
# processing record 774, Ryoko's
# processing record 775, Bohemian Club
# Restaurant not found... skipping.
# processing record 776, Venticello Ristorante
# processing record 777, Pacific Union Club
# Restaurant not found... skipping.
# processing record 778, Starbucks Coffee
# Restaurant not found... skipping.
# processing record 779, City View Restaurant
# processing record 780, Boudin Bakery
# processing record 781, Hyatt Regency - Main Kitchen, Employees Cafeteria
# processing record 782, Eclipse Cafe
# processing record 783, Bix
# processing record 784, Bow Hon Restaurant
# processing record 785, Golden Gate Bakery
# processing record 786, Villa Taverna
# processing record 787, Great Eastern Restaurant
# processing record 788, Mrs. T's Cafe
# Restaurant not found... skipping.
# processing record 789, Penang Garden  Restaurant
# processing record 790, Golden Star Vietnamese Restaurant
# processing record 791, Noah's New York Bagels #2113
# Restaurant not found... skipping.
# processing record 792, Herlen Place
# processing record 793, Lee's Deli
# processing record 794, Mixed Greens Prep Kitchen
# processing record 795, Mandalay Restaurant
# processing record 796, CITY CLUB
# Restaurant not found... skipping.
# processing record 797, Neiman Marcus - Rotunda
# processing record 798, The Pig & Whistle
# Restaurant not found... skipping.
# processing record 799, SUPERIOR PALACE SEAFOOD REST.
# processing record 800, TON KIANG RESTAURANT #2
# processing record 801, CELIAS RESTAURANT
# processing record 802, SAFEWAY #785
# Restaurant not found... skipping.
# processing record 803, MARCELLOS
# processing record 804, Station Cafe
# processing record 805, ABSINTHE BRASSERIE & BAR
# processing record 806, IL PIRATA
# Restaurant not found... skipping.
# processing record 807, Taqueria "Los Coyotes" #2
# processing record 808, TARTINE BAKERY
# processing record 809, THE LIBERTIES IRISH BAR & REST.
# processing record 810, JIM'S RESTAURANT
# processing record 811, CHAVA'S
# processing record 812, Beretta
# processing record 813, MAD DOG IN THE FOG
# Restaurant not found... skipping.
# processing record 814, NOC NOC
# Restaurant not found... skipping.
# processing record 815, HAYES STREET GRILL
# processing record 816, ABSINTHE PASTRY
# Restaurant not found... skipping.
# processing record 817, SUPPENKUCHE
# processing record 818, ZUNI CAFE
# processing record 819, SAFEWAY #1490
# Restaurant not found... skipping.
# processing record 820, PANCHO VILLA
# processing record 821, VERDI CLUB
# Restaurant not found... skipping.
# processing record 822, SQUAT & GOBBLE CAFE #4
# Restaurant not found... skipping.
# processing record 823, LA CUMBRE
# processing record 824, Tower Carwash
# Restaurant not found... skipping.
# processing record 825, Holiday Inn - Golden Gateway
# Restaurant not found... skipping.
# processing record 826, Chinatown Restaurant
# processing record 827, Mollie Stone's Tower Market
# Restaurant not found... skipping.
# processing record 828, ROUND TABLE PIZZA
# processing record 829, BENIHANA OF TOKYO
# Restaurant not found... skipping.
# processing record 830, NEW HING LUNG RESTAURANT
# processing record 831, MATTERHORN RESTAURANT
# processing record 832, Zingari
# processing record 833, WE BE SUSHI
# processing record 834, ACE WASABI'S ROCK N ROLL SUSHI
# processing record 835, GOLD CLUB, THE
# Restaurant not found... skipping.
# processing record 836, JARDINIERE RESTAURANT
# processing record 837, SAFEWAY #2646
# Restaurant not found... skipping.
# processing record 838, CINDERELLA BAKERY & CAFE
# processing record 839, BRYAN'S
# Restaurant not found... skipping.
# processing record 840, ROUND TABLE PIZZA RESTAURANT
# processing record 841, Pauline's Pizza
# processing record 842, BURGER KING
# processing record 843, BLOWFISH SUSHI
# processing record 844, Biscuits & Blues
# processing record 845, French Club
# processing record 846, Johnny Foley's Irish House
# processing record 847, MARRAKECH MORROCAN RESTAURANT
# processing record 848, Metropolitan Club
# Restaurant not found... skipping.
# processing record 849, Washington Bakery & Restaurant
# processing record 850, Happy Chinese Restaurant
# processing record 851, SAFEWAY #667
# Restaurant not found... skipping.
# processing record 852, COVE CAFE
# processing record 853, SAFEWAY #1507
# Restaurant not found... skipping.
# processing record 854, CAFE PICARO
# processing record 855, EL TORO TAQUERIA
# processing record 856, WARAKABUNE RESTAURANT
# processing record 857, Thai House Express On Castro
# processing record 858, RAINBOW GROCERY
# Restaurant not found... skipping.
# processing record 859, HUNAN RESTAURANT
# processing record 860, THIRSTY BEAR BREWING CO
# processing record 861, CINCO DE MAYO TAQUERIA & GROCERY
# Restaurant not found... skipping.
# processing record 862, IMPERIAL GARDEN SEAFOOD RESTAURANT
# processing record 863, Bacco
# processing record 864, BARNEY'S
# processing record 865, SAFEWAY #739
# Restaurant not found... skipping.
# processing record 866, LA ALTENA
# processing record 867, MARINA SUPER
# processing record 868, BALBOA CAFE
# processing record 869, IZZY'S STEAK & CHOP HOUSE
# processing record 870, PORTICO
# Restaurant not found... skipping.
# processing record 871, Cable Car Restaurant
# Restaurant not found... skipping.
# processing record 872, FIREWOOD CAFE
# processing record 873, St. Francis Memorial Hospital - Employees Cafeteria
# Restaurant not found... skipping.
# processing record 874, BOSTON MARKET
# processing record 875, Ladle and Leaf
# processing record 876, Espetus Churrascaria, Inc.
# processing record 877, OPERA HOUSE - BASEMENT,LOWER LOUNGE
# Restaurant not found... skipping.
# processing record 878, Le Colonial, SF, LLC
# processing record 879, Boudin Bakery
# Restaurant not found... skipping.
# processing record 880, Mel's Drive-In
# Restaurant not found... skipping.
# processing record 881, KIRIN RESTAURANT
# processing record 882, Trattoria Pinocchio
# processing record 883, Hornblower Cruises & Events/Hornblower-Santa Rosa
# Restaurant not found... skipping.
# processing record 884, GAP INC.
# Restaurant not found... skipping.
# processing record 885, CROSSROADS CAFE
# processing record 886, EUREST DINING SERVICES
# Restaurant not found... skipping.
# processing record 887, SEASONS BAR
# processing record 888, SLIM'S
# processing record 889, SING SING
# processing record 890, EDINBURGH CASTLE PUB
# Restaurant not found... skipping.
# processing record 891, Ferry Plaza Wine Merchant
# Restaurant not found... skipping.
# processing record 892, BIN 55
# processing record 893, Roaring 20's
# processing record 894, Hustler Club
# Restaurant not found... skipping.
# processing record 895, Shannon Arms
# Restaurant not found... skipping.
# processing record 896, Hornblower Cruises & Events/SF Belle
# Restaurant not found... skipping.
# processing record 897, FINAL FINAL
# Restaurant not found... skipping.
# processing record 898, The Grand Nightclub
# processing record 899, Holiday Inn Fisherman's Wharf
# Restaurant not found... skipping.
# processing record 900, SOUTH BEACH YACHT CLUB
# Restaurant not found... skipping.
# processing record 901, GLENEAGLES GOLF COURSE AT M P
# Restaurant not found... skipping.
# processing record 902, Ritz-Carlton SF - Bakery
# Restaurant not found... skipping.
# processing record 903, The Page
# Restaurant not found... skipping.
# processing record 904, Cafe Du Soleil
# processing record 905, DIVA'S
# Restaurant not found... skipping.
# processing record 906, ASIA SF LLC
# Restaurant not found... skipping.
# processing record 907, BOTTOM OF THE HILL
# Restaurant not found... skipping.
# processing record 908, Barbarossa
# processing record 909, Sweetie's
# Restaurant not found... skipping.
# processing record 910, Crepe Cafe
# processing record 911, NOE VALLEY BAKERY & BREAD CO.
# Restaurant not found... skipping.
# processing record 912, DIANA MARKET #2
# ...
# processing record 5366, 95194 Doggie Diner Cart
# Restaurant not found... skipping.
# processing record 5367, Greaser Coffee
# Restaurant not found... skipping.
# processing record 5368, 95201 Zach's Deli
# Restaurant not found... skipping.
# processing record 5369, 95202 Mission Street Nacho Cart
# processing record 5370, 95205 Popcorn Cart
# Restaurant not found... skipping.
# processing record 5371, 95206 King Street Carvery (Soup) Cart
# Restaurant not found... skipping.
# processing record 5372, 95209  Popcorn Cart
# Restaurant not found... skipping.
# processing record 5373, 95212 Doggie Diner
# Restaurant not found... skipping.
# processing record 5374, 95215  Carvery Cart
# Restaurant not found... skipping.
# processing record 5375, 95216 - Ballpark Snacks Stand
# Restaurant not found... skipping.
# processing record 5376, 95219 Doggie Diner
# Restaurant not found... skipping.
# processing record 5377, 95222 - V-4 King Street Carvery (Cart)
# Restaurant not found... skipping.
# processing record 5378, 95224 Doggie Diner
# Restaurant not found... skipping.
# processing record 5379, 95228 The Carvery
# Restaurant not found... skipping.
# processing record 5380, 95229 Outta Here Cheesesteak
# processing record 5381, 95231 Doggie Diner Cart
# Restaurant not found... skipping.
# processing record 5382, 95232 Say Hey Sausage Cart
# Restaurant not found... skipping.
# processing record 5383, 95235 Farmers Market/Snack
# Restaurant not found... skipping.
# processing record 5384, 95239 Popcorn Cart
# Restaurant not found... skipping.
# processing record 5385, 95245 Doggie Diner/Taqueria
# processing record 5386, 95246 Main Warehouse Storage & Walk-in Boxes
# Restaurant not found... skipping.
# processing record 5387, 95247 Doggie Diner
# Restaurant not found... skipping.
# processing record 5388, 95248 Liquor Room & Walk-in Box
# Restaurant not found... skipping.
# processing record 5389, 95250 C&C Concessions/View Level Vending Room
# Restaurant not found... skipping.
# processing record 5390, 95252 C&C Concessions/Portable 331 Lemonade Snack Cart
# Restaurant not found... skipping.
# processing record 5391, 95253 C&C Concessions/Portable 142 Lemonade Cart
# Restaurant not found... skipping.
# processing record 5392, 95256 C&C Concessions/Portable 115 Lemonade Snack Cart
# Restaurant not found... skipping.
# processing record 5393, 95305 C&C Concessions/Portable 214 Lemonade Snack Cart
# Restaurant not found... skipping.
# processing record 5394, 95310 C&C Concessions/Portable 318 Lemonade Snack Cart
# Restaurant not found... skipping.
# processing record 5395, 95311 C&C Concessions/Portable 130 Lemonade Snack Cart
# Restaurant not found... skipping.
# processing record 5396, 95312 C&C Concessions/Portable 311 Lemonade Snack Cart
# Restaurant not found... skipping.
# processing record 5397, 95313 C&C Concessions/Main Vending Commissary Room
# Restaurant not found... skipping.
# processing record 5398, 1608 Bistro
# processing record 5399, Toppu Ramen & Dim Sum House
# processing record 5400, Back Room
# processing record 5401, The Rainbow
# Restaurant not found... skipping.
# processing record 5402, San Marcos Restaurante
# Restaurant not found... skipping.
# processing record 5403, Blue Fog Market
# processing record 5404, Bowl'D Acai
# Restaurant not found... skipping.
# processing record 5405, La Fromagerie
# Restaurant not found... skipping.
# processing record 5406, Monster Chef
# Restaurant not found... skipping.
# processing record 5407, The Fog Lifter Cafe
# processing record 5408, Bake Cheese Tart
# Restaurant not found... skipping.
# processing record 5409, Grinders Pizzaeria
# Restaurant not found... skipping.
# processing record 5410, Bing & Boba
# processing record 5411, Gong Cha
# Restaurant not found... skipping.
# processing record 5412, Mixt Greens / Mixt
# processing record 5413, Starbucks #52861
# Restaurant not found... skipping.
# processing record 5414, T Cup Cafe
# Restaurant not found... skipping.
# processing record 5415, SF Hole in The Wall Pizza
# processing record 5416, Eat Sushi
# processing record 5417, Golden Coffee
# processing record 5418, Cracked & Battered
# processing record 5419, Wezy
# Restaurant not found... skipping.
# processing record 5420, Karma Cafe
# processing record 5421, Quickly Tea Plus Tea Bar
# Restaurant not found... skipping.
# processing record 5422, Altalena Vinoteca
# processing record 5423, Z Zoul Cafe
# processing record 5424, Urban Ritual
# processing record 5425, The Grub-Bies LLC
# Restaurant not found... skipping.
# processing record 5426, Umo BBQ, LLC
# Restaurant not found... skipping.
# processing record 5427, Cafe Guatemalteco
# processing record 5428, Phillmore Creamery
# Restaurant not found... skipping.
# processing record 5429, Otoro
# processing record 5430, Mustafio"s Pizza
# processing record 5431, Joe & The Juice- 303 2nd Street
# processing record 5432, Chocolate Chair Union Square
# Restaurant not found... skipping.
# processing record 5433, Spice Kitchen
# processing record 5434, Neighbors Corner
# Restaurant not found... skipping.
# processing record 5435, Canopy
# Restaurant not found... skipping.
# processing record 5436, Double Decker
# processing record 5437, SusieCakes Bakery
# Restaurant not found... skipping.
# processing record 5438, Mainland Market
# Restaurant not found... skipping.
# processing record 5439, Ichiraku Ramen
# processing record 5440, Fools Errand
# Restaurant not found... skipping.
# processing record 5441, Anton's Pizza
# processing record 5442, Z & Y Bistro
# processing record 5443, Irving Pizza
# processing record 5444, Crave Subs
# processing record 5445, The Korean Kitchen
# processing record 5446, Bon Appetit @ Airbnb
# Restaurant not found... skipping.
# processing record 5447, STONE KOREAN KITCHEN
# processing record 5448, The Fruit Tree
# Restaurant not found... skipping.
# processing record 5449, Donna's Tamales
# Restaurant not found... skipping.
# processing record 5450, Kurotaka Ramen
# Restaurant not found... skipping.
# processing record 5451, Black Sugar
# Restaurant not found... skipping.
# processing record 5452, Taco El Ojo de Agua #2
# Restaurant not found... skipping.
# processing record 5453, Poke Delish
# Restaurant not found... skipping.
# processing record 5454, Sightglass Coffee
# processing record 5455, DIJON BURGER
# processing record 5456, Fig & Thistle Market
# Restaurant not found... skipping.
# processing record 5457, Alembic, SF
# processing record 5458, THE SALAD PLACE & ROTISSERIE
# processing record 5459, Starbucks Coffee #54768
# Restaurant not found... skipping.
# processing record 5460, TARARA
# processing record 5461, Itzae
# Restaurant not found... skipping.
# processing record 5462, Ambrosia INC
# Restaurant not found... skipping.
# processing record 5463, El Rancho Grande Taqueria
# processing record 5464, Crepe & Curry
# processing record 5465, Heavenly Cafe
# processing record 5466, Golden State Grill
# processing record 5467, Panchitas
# processing record 5468, PEET'S COFFEE AND TEA INC
# Restaurant not found... skipping.
# processing record 5469, SAJJ``
# processing record 5470, Mauer Park
# processing record 5471, Your Way to Life Foods
# Restaurant not found... skipping.
# processing record 5472, USHITARO
# Restaurant not found... skipping.
# processing record 5473, HARVEST WHEATFIELD BAKERY
# Restaurant not found... skipping.
# processing record 5474, CTR FOR URBAN EDU ABOUT SU AGR
# Restaurant not found... skipping.
# processing record 5475, DOUGLAS
# processing record 5476, LA FLOR DE IZOTE
# Restaurant not found... skipping.
# processing record 5477, SANPPO RESTAURANT
# processing record 5478, COCO FRESH TEA & JUICE
# Restaurant not found... skipping.
# processing record 5479, THE LUCKY PIG
# processing record 5480, KKOCHI KOREAN BBQ RESTAURANT
# processing record 5481, LUKE'S LOBSTER
# processing record 5482, AVEDANO'S HOLLY PARK MARKET
# Restaurant not found... skipping.
# processing record 5483, GOCHEES PIZZA
# processing record 5484, SUSHI SHOH
# processing record 5485, GOOOD FORTUNE LLC.
# Restaurant not found... skipping.
# processing record 5486, JOE & THE JUICE - 1155 4TH STREET
# Restaurant not found... skipping.
# processing record 5487, VAN NESS CAFE & GYROS
# processing record 5488, OCEAN BLUE LAUNDRY & CAFE
# processing record 5489, VENUS CAFE
# processing record 5490, JASPER'S CORNER TAP & KITCHEN
# processing record 5491, SAN FRANCISCO WINE AND CHEESE
# processing record 5492, MAI MAI SANDWICH & BAKERY
# processing record 5493, HAKKA RESTAURANT
# processing record 5494, Cups and Cakes Bakery
# Restaurant not found... skipping.
# processing record 5495, The Story of Ramen
# Restaurant not found... skipping.
# processing record 5496, Mama Coco's Restuarant
# Restaurant not found... skipping.
# processing record 5497, LEFTYS BALLPARK BUFFET
# processing record 5498, 903
# Restaurant not found... skipping.
# processing record 5499, EL CAFE
# processing record 5500, PALACE OF SPICES
# processing record 5501, CAPTAIN KONA CAFE
# processing record 5502, SNOW GARDEN EXPRESS
# processing record 5503, SAFFA HOME FOODS
# Restaurant not found... skipping.
# processing record 5504, SORABOL KOREAN BBQ AND ASIAN NOODLES
# Restaurant not found... skipping.
# processing record 5505, PRESIDIO PIZZA COMPANY
# processing record 5506, PARAMOUNT SUPERSTARS, INC.
# Restaurant not found... skipping.
# processing record 5507, WORD A CAFE
# processing record 5508, BELLO COFFEE LLC
# Restaurant not found... skipping.
# processing record 5509, Caffea
# Restaurant not found... skipping.
# processing record 5510, MR. EAST KITCHEN
# processing record 5511, LOVESSY
# processing record 5512, MENDOCINO FARMS
# processing record 5513, Spunbyss
# Restaurant not found... skipping.
# processing record 5514, HARDWOOD BAR & SMOKERY
# processing record 5515, POKE REESE
# Restaurant not found... skipping.
# processing record 5516, FREDS AT BARNEYS NEW YORK
# processing record 5517, FISHERMAN'S GROTTO NO. 9
# Restaurant not found... skipping.
# processing record 5518, FRENA
# processing record 5519, Curveball
# Restaurant not found... skipping.
# processing record 5520, METRO HONG KONG DESSERT
# Restaurant not found... skipping.
# processing record 5521, FIRE AND BREW
# Restaurant not found... skipping.
# processing record 5522, MANNY'S
# processing record 5523, NEXT LEVEL BURGER COMPANY, INC.
# Restaurant not found... skipping.
# processing record 5524, SENIORES PIZZA
# Restaurant not found... skipping.
# processing record 5525, SCULLERY INC
# Restaurant not found... skipping.
# processing record 5526, DOPPIO ZERO
# processing record 5527, CHOMP N' SWIG
# processing record 5528, TROJE
# processing record 5529, KAIYO RESTAURANT & BAR
# processing record 5530, OYE MANAGUA
# processing record 5531, TWIN PEAKS CAFE
# Restaurant not found... skipping.
# processing record 5532, HAPPY DONUTS
# Restaurant not found... skipping.
# processing record 5533, GREAT MONGOLIA
# processing record 5534, BITEUNITE OF USA LLC
# Restaurant not found... skipping.
# processing record 5535, TOSAI
# processing record 5536, EL PIPILA
# processing record 5537, IZUMI KAITEN SUSHI
# processing record 5538, FIRE 2 SMOKE
# Restaurant not found... skipping.
# processing record 5539, ASHLEY'S CAFE
# processing record 5540, PRAIRIE
# processing record 5541, BAY RETAIL VFSF
# Restaurant not found... skipping.
# processing record 5542, SNEAKYS BBQ LLC
# Restaurant not found... skipping.
# processing record 5543, KIBATSU
# processing record 5544, SNOWFLAKE TREATS
# Restaurant not found... skipping.
# processing record 5545, PIRI PICA
# processing record 5546, FAT BELI DELI
# processing record 5547, Sabor Catracho
# Restaurant not found... skipping.
# processing record 5548, Moscone South Main Kitchen
# Restaurant not found... skipping.
# processing record 5549, CUP+FORK
# Restaurant not found... skipping.
# processing record 5550, SHIHLIN
# processing record 5551, VEGAN-N-KABOB
# processing record 5552, FULLSKOOP, INC.
# Restaurant not found... skipping.
# processing record 5553, ELIXART
# processing record 5554, MANSION ON SUTTER
# processing record 5555, THE ITALIAN HOMEMADE COMPANY
# processing record 5556, THE CHURRO FACTORY
# Restaurant not found... skipping.
# processing record 5557, PUSHCART FARE
# processing record 5558, ISLAVIDA
# Restaurant not found... skipping.
# processing record 5559, FISTFUL OF TACOS
# processing record 5560, BICYCLE BANH MI INC.
# Restaurant not found... skipping.
# processing record 5561, LITTLE SUSHI BAR
# processing record 5562, PLATFORM 248
# Restaurant not found... skipping.
# processing record 5563, CHARLES CHOCOLATES
# Restaurant not found... skipping.
# processing record 5564, HARBORVIEW RESTAURANT & BAR
# Restaurant not found... skipping.
# processing record 5565, HOUSE OF BAGELS AT MASON
# Restaurant not found... skipping.
# processing record 5566, ARAMEX
# processing record 5567, MUGUBOKA RESTAURANT
# processing record 5568, AN CHI
# processing record 5569, HOT SPUD
# processing record 5570, KIKKA AT GAP
# Restaurant not found... skipping.
# processing record 5571, GAI
# processing record 5572, PIZZERIA DELFINA
# processing record 5573, PING & YANG
# processing record 5574, NOMMO
# processing record 5575, BREADBELLY
# processing record 5576, Sumo
# processing record 5577, FOGCUTTERSF
# Restaurant not found... skipping.
# processing record 5578, HON'S WUN TUN HOUSE
# processing record 5579, BAZAAR CAFE
# processing record 5580, FORMICA TABLE LLC
# Restaurant not found... skipping.
# processing record 5581, SASA JAPANESE RESTAURANT
# Restaurant not found... skipping.
# processing record 5582, HING WAH FENG
# Restaurant not found... skipping.
# processing record 5583, TASTY RESTAURANT
# processing record 5584, PHO 335
# processing record 5585, BLUESTONE LANE
# processing record 5586, EL RINCONCITO CATRACHO 2
# Restaurant not found... skipping.
# processing record 5587, MISSION PREPARATORY INC
# Restaurant not found... skipping.
# processing record 5588, USAGI
# processing record 5589, GUSTO MEDITERRANEO
# Restaurant not found... skipping.
# processing record 5590, TAQUERIA LA PAZ
# Restaurant not found... skipping.
# processing record 5591, TY PHO
# processing record 5592, ST. THOMAS MORE ELEMENTARY SCHOOL
# Restaurant not found... skipping.
# processing record 5593, MoMo Noodle
# Restaurant not found... skipping.
# processing record 5594, YOSOYCEVICHE
# Restaurant not found... skipping.
# processing record 5595, BIG CITY MONTESSORI SCHOOL
# Restaurant not found... skipping.
# processing record 5596, ZHUO KITCHEN
# processing record 5597, LAGUNA
# processing record 5598, BROWN SUGAR KITCHEN
# Restaurant not found... skipping.
# processing record 5599, SWEET MANGO DESSERT & CAFE
# processing record 5600, BREAKFAST AT THE CAMPER
# Restaurant not found... skipping.
# processing record 5601, TWO SONS SANDWICHES
# processing record 5602, 333 Truck
# Restaurant not found... skipping.
# processing record 5603, #1 VERJUS CAVE, #2 VERJUS
# Restaurant not found... skipping.
# processing record 5604, JANCHAY'S BISTRO.
# processing record 5605, CHAIRMAN SF, LLC
# Restaurant not found... skipping.
# processing record 5606, BOYS DELI INC
# Restaurant not found... skipping.
# processing record 5607, TURO CAFE AND GRILL LLC
# Restaurant not found... skipping.
# processing record 5608, MANGO CRAZY
# Restaurant not found... skipping.
# processing record 5609, CROSSROAD PIZZERIA
# processing record 5610, THE LINKS BAR AND GRILL
# processing record 5611, TAYLOR LANE ORGANIC COFFEE
# Restaurant not found... skipping.
# processing record 5612, BLUESTONE LANE
# processing record 5613, POMELO ON CHURCH
# processing record 5614, LING LING CUISINE RESTAURANT
# processing record 5615, KRISPY KRUNCHY CHICKEN
# processing record 5616, THE BAGEL BAKERY CAFE
# processing record 5617, ROTI INDIAN BISTRO LLC
# Restaurant not found... skipping.
# processing record 5618, LOVING CUP OCTAVIA
# processing record 5619, HAPPY DONUTS
# Restaurant not found... skipping.
# processing record 5620, ONE BOILING POT
# processing record 5621, The Upper Crust Baking Co. Inc
# Restaurant not found... skipping.
# processing record 5622, Fruity Moto
# Restaurant not found... skipping.
# processing record 5623, BOOM CHICKA COW
# Restaurant not found... skipping.
# processing record 5624, B & B CAFE
# processing record 5625, Mashallah Halal Food truck Ind
# Restaurant not found... skipping.
# processing record 5626, Marley's Streats
# Restaurant not found... skipping.
# processing record 5627, GOLDEN STATE PIZZA AND GRILL
# processing record 5628, MARVIN GARDENS
# Restaurant not found... skipping.
# ---------------------------
# All restaurants processed!!
# ---------------------------

# %%
yelp_df["restaurant"].count()
# Out:
# 5629

# %%
yelp_df = yelp_df.dropna(subset=['yelp_business_id'])
yelp_df.count()
# Out:
# restaurant              2880
# address                 2880
# recent_health_score     2880
# recent_health_risk      2790
# average_health_score    2880
# zipcode                 2880
# yelp_business_id        2880
# rating                  2880
# price                   2880
# review_count            2880
# category_1              2880
# category_2              2880
# category_3              2880
# distance                2880
# dtype: int64

# %%
# Export file as a CSV, without the Pandas index, but with the header
# yelp_df.to_csv("/resources/yelp_ratings.csv", index=False, header=True)

# %% [markdown]
# ### Clean up extraneous data

# %%
# Input File (CSV) and initialize the yelp data
#input_data_file = "resources/yelp_ratings.csv"
#yelp_df = pd.read_csv(input_data_file)
#yelp_df["restaurant"].count()
# Out:
# 3970

# %%
only_restaurants = yelp_df.loc[(yelp_df["category_1"] != "Elementary Schools") &
                               (yelp_df["category_1"] != "Gyms") &
                               (yelp_df["category_1"] != "Educational Services") &
                               (yelp_df["category_1"] != "Grocery") &
                               (yelp_df["category_1"] != "Hotels") &
                               (yelp_df["category_1"] != "Sports Teams") &
                               (yelp_df["category_1"] != "Shared Office Spaces") &
                               (yelp_df["category_1"] != "Preschools") &
                               (yelp_df["category_1"] != "Child Care") &
                               (yelp_df["category_1"] != "Retirement Homes") &
                               (yelp_df["category_1"] != "Boating") &
                               (yelp_df["category_1"] != "Country Clubs") &
                               (yelp_df["category_1"] != "Tennis") &
                               (yelp_df["category_1"] != "Cinema") &
                               (yelp_df["category_1"] != "Performing Arts") &
                               (yelp_df["category_1"] != "Golf") &
                               (yelp_df["category_1"] != "Real Estate Agents") &
                               (yelp_df["category_1"] != "Car Wash") &
                               (yelp_df["category_1"] != "Synagogues") &
                               (yelp_df["category_1"] != "Churches") &
                               (yelp_df["category_1"] != "Hospice") &
                               (yelp_df["category_1"] != "Rehabilitation Center") &
                               (yelp_df["category_1"] != "Community Service/Non-Profit") &
                               (yelp_df["category_1"] != "Art Museums") &
                               (yelp_df["category_1"] != "Zoos") &
                               (yelp_df["category_1"] != "Neurologist") &
                               (yelp_df["category_1"] != "Middle Schools & High Schools") &
                               (yelp_df["category_1"] != "Thrift Stores") &
                               (yelp_df["category_1"] != "Senior Centers") &
                               (yelp_df["category_1"] != "Medical Centers") &
                               (yelp_df["category_1"] != "Smog Check Stations") &
                               (yelp_df["category_1"] != "Gas Stations") &
                               (yelp_df["category_1"] != "Car Wash") &
                               (yelp_df["category_1"] != "Naturopathic/Holistic") &
                               (yelp_df["category_1"] != "Public Transportation") &
                               (yelp_df["category_1"] != "Special Education") &
                               (yelp_df["category_1"] != "Swimming Pools") &
                               (yelp_df["category_1"] != "Parking") &
                               (yelp_df["category_1"] != "Drug Stores") &
                               (yelp_df["category_1"] != "Cooking Schools") &
                               (yelp_df["category_1"] != "Software Development") &
                               (yelp_df["category_1"] != "Wholesale Stores") &
                               (yelp_df["category_1"] != "Boot Camps") &
                               (yelp_df["category_1"] != "Laundromat") &
                               (yelp_df["category_1"] != "Vinyl Records") &
                               (yelp_df["category_1"] != "Art Galleries") &
                               (yelp_df["category_1"] != "Social Clubs") , :]

# %%
less_restaurants = only_restaurants.loc[(yelp_df["category_1"] != "") &
                               (yelp_df["category_1"] != "Museums") &
                               (yelp_df["category_1"] != "Professional Sports Teams") &
                               (yelp_df["category_1"] != "Arcades") &
                               (yelp_df["category_1"] != "Child Care & Day Care") &
                               (yelp_df["category_1"] != "CSA") &
                               (yelp_df["category_1"] != "Gift Shops") &
                               (yelp_df["category_1"] != "Internet Cafes") &
                               (yelp_df["category_1"] != "Shopping Centers") &
                               (yelp_df["category_1"] != "Bookstores") &
                               (yelp_df["category_1"] != "Bowling") &
                               (yelp_df["category_1"] != "Colleges & Universities") &
                               (yelp_df["category_1"] != "Cosmetics & Beauty Supply") &
                               (yelp_df["category_1"] != "Florists") &
                               (yelp_df["category_1"] != "Mini Golf") &
                               (yelp_df["category_1"] != "Montessori Schools") &
                               (yelp_df["category_1"] != "Parking") &
                               (yelp_df["category_1"] != "Public Services & Government") &
                               (yelp_df["category_1"] != "Reflexology") &
                               (yelp_df["category_1"] != "Shopping") &
                               (yelp_df["category_1"] != "Thrift Stores") &
                               (yelp_df["category_1"] != "Tobacco Shops") &
                               (yelp_df["category_1"] != "Trainers") &
                               (yelp_df["category_1"] != "Videos & Video Game Rental") , :]

# %%
less_restaurants["restaurant"].count()
# Out:
# 3519

# %%
group = less_restaurants.groupby("category_1").count()
cuisine = group.sort_values("restaurant", ascending=False)
print(cuisine["restaurant"])
# Out:
# category_1
# Coffee & Tea                 332
# Mexican                      164
# Chinese                      159
# Pizza                        153
# Bakeries                     131
# American (New)               130
# Sandwiches                   120
# Italian                      113
# Sushi Bars                    94
# Japanese                      93
# Vietnamese                    90
# Thai                          77
# American (Traditional)        68
# Breakfast & Brunch            68
# Cafes                         62
# Burgers                       58
# Indian                        57
# Delis                         56
# Seafood                       56
# Beer, Wine & Spirits          55
# Ice Cream & Frozen Yogurt     51
# Bars                          49
# Wine Bars                     46
# Dim Sum                       43
# Food Trucks                   41
# Korean                        40
# Juice Bars & Smoothies        37
# Mediterranean                 36
# French                        33
# Fast Food                     33
#                             ...
# Teppanyaki                     1
# Belgian                        1
# Beer Gardens                   1
# Bed & Breakfast                1
# Argentine                      1
# Arabian                        1
# Vitamins & Supplements         1
# Sports Clubs                   1
# Hookah Bars                    1
# Champagne Bars                 1
# Nicaraguan                     1
# Pool Halls                     1
# Fish & Chips                   1
# Pretzels                       1
# Piano Bars                     1
# Empanadas                      1
# Gay Bars                       1
# Pakistani                      1
# Nightlife                      1
# New Mexican Cuisine            1
# Pool & Billiards               1
# Cupcakes                       1
# Senegalese                     1
# Cooking Classes                1
# Shaved Snow                    1
# Singaporean                    1
# Comedy Clubs                   1
# Afghan                         1
# South African                  1
# Karaoke                        1
# Name: restaurant, Length: 179, dtype: int64

# %%
# reduce the categories to the top 10
def category(food):
    if (food == "American (New)") | (food == "American (Traditional)"):
        food= 'American'
    elif food == 'Chinese':
        food = 'Chinese'
    elif (food == 'Conveyor Belt Sushi') | (food =='Japanese') | (food == 'Japanese Curry') | (food == 'Sushi Bars'):
        food =  'Japanese'
    elif food == 'Indian' :
        food = 'Indian'
    elif (food == 'Italian') | (food == 'Pizza'):
        food = 'Italian'
    elif food =='Korean':
        food = 'Korean'
    elif (food == 'Mediterranean') | (food == 'Middle Eastern') | (food == 'Greek'):
        food = 'Mediterranean'
    elif (food == 'Mexican') | (food == 'New Mexican Cuisine'):
        food = 'Mexican'
    elif (food =='Thai'):
        food = 'Thai'
    elif food == 'Vietnamese':
        food = 'Vietnamese'
    else:
        food = 'Other'
    return food

# %%
less_restaurants["cuisine"] = less_restaurants["category_1"].apply(category)
less_restaurants.head()
# Out:
# C:\Users\caeeb\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        restaurant              address  recent_health_score  \
# 0  Norman's Ice Cream and Freezes  2801 Leavenworth St                   96
# 1             CHARLIE'S DELI CAFE       3202 FOLSOM St                   88
# 2                      ART'S CAFE        747 IRVING St                   94
# 4                      CAFE X + O       1799 Church St                   92
# 5                     Oasis Grill          91 Drumm St                   70
#
#   recent_health_risk  average_health_score  zipcode        yelp_business_id  \
# 0           Low Risk             96.000000  94133.0  sfAIpzEC8ywpy36YhzikmQ
# 1           Low Risk             86.315789  94117.0  hNze7c3mWvEnAXYT_geV9Q
# 2           Low Risk             90.500000  94122.0  MXKWFQHoC0SXy9UI-Djn7g
# 4           Low Risk             91.750000  94131.0  HhAmBwTYq_MXbOLzypRQjQ
# 5           Low Risk             72.454545  94111.0  gBRjRvIfA4fIo6pNebTjuA
#
#    rating price  review_count                 category_1    category_2  \
# 0     4.5     $         289.0  Ice Cream & Frozen Yogurt  Coffee & Tea
# 1     4.5     $          82.0                      Delis    Sandwiches
# 2     4.0     $        1069.0                     Diners        Korean
# 4     3.5     $         223.0               Coffee & Tea    Sandwiches
# 5     4.0    $$        1199.0              Mediterranean      Desserts
#
#                category_3   distance        cuisine
# 0  Juice Bars & Smoothies   8.031888          Other
# 1                     NaN  11.894793          Other
# 2  American (Traditional)   8.885345          Other
# 4                     NaN   7.502404          Other
# 5                   Salad   5.072415  Mediterranean

# %%
# Export file as a CSV, without the Pandas index, but with the header
less_restaurants.to_csv("resources/yelp_clean.csv", index=False, header=True)
