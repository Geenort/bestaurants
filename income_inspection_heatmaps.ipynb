# %%
import gmaps
import pandas as pd

#from config import trongkey

gmaps.configure(api_key="AIzaSyAu0g-0kWOWsa8A0FBPE-hzkxNUz62hLxA")

# %%
main_df = pd.read_csv('all_data_cleaned.csv')
main_df.head()
# Out:
#    Unnamed: 0                      restaurant              address  \
# 0           0  Norman's Ice Cream and Freezes  2801 Leavenworth St
# 1           1                        Chowders    Pier 39  Space A3
# 2           2                    XOX Truffles     754 Columbus Ave
# 3           3                     Centerfolds      391 Broadway St
# 4           4                   Caffe Puccini     411 Columbus Ave
#
#    recent_health_score recent_health_risk  average_health_score  zipcode  \
# 0                   96           Low Risk             96.000000    94133
# 1                   98           Low Risk             94.500000    94133
# 2                   94      Moderate Risk             94.000000    94133
# 3                   90           Low Risk             90.857143    94133
# 4                   90           Low Risk             90.000000    94133
#
#          yelp_business_id  rating price  review_count  \
# 0  sfAIpzEC8ywpy36YhzikmQ     4.5     $         289.0
# ...

# %%
# group by zip, to make heat maps
zip_grp = main_df.groupby('zipcode', as_index=False)
zip_df = zip_grp.mean()
zip_df
sf_zip_df = zip_df[(zip_df.zipcode != 90012) &
                   (zip_df.zipcode != 94301) &
                   (zip_df.zipcode != 94619) &
                   (zip_df.zipcode != 94931) &
                   (zip_df.zipcode != 94019)]
sf_zip_df
# Out:
#     zipcode  Unnamed: 0  recent_health_score  average_health_score    rating  \
# 2     94102      1552.0            89.890566             89.238106  3.775472
# 3     94103      1914.0            88.760943             88.014189  3.843434
# 4     94104      1725.0            89.234568             88.021733  3.771605
# 5     94105      2222.5            87.950820             87.274068  3.606557
# 6     94107       824.5            90.279221             89.719346  3.831169
# 7     94108      1347.5            89.868056             88.288953  3.715278
# 8     94109      3117.5            89.245902             88.318253  3.862705
# 9     94110      1088.5            88.802139             88.698007  3.941176
# 10    94111       671.5            91.164474             89.827736  3.700658
# 11    94112      2685.0            86.247934             85.924226  3.789256
# 12    94114      3310.0            90.163121             90.684427  3.907801
# ...

# %%
locations = sf_zip_df[['zip_lat','zip_lng']]
inspection_scores = sf_zip_df['recent_health_score']
income = sf_zip_df['median_income']

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=inspection_scores, 
                                 dissipating=True,
                                 point_radius=10,
                                 gradient=[(255,255,255,0),
                                           (0,50,0),
                                           (0,100,0),
                                           (0,200,0),
                                           (0,255,0)])

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plot Heatmap
fig2 = gmaps.figure()

# Create heat layer
heat_layer2 = gmaps.heatmap_layer(locations, weights=income, 
                                 dissipating=True,
                                 point_radius=15,
                                 gradient=[(255,255,255,0.5),
                                           (0,255,0,1),
                                           #(0,200,0,1),
                                           #(0,150,0,1),
                                           #(0,100,0,1),
                                           #(0,50,0,1),
                                           (0,0,0,1)])

# Add layer
fig2.add_layer(heat_layer2)

# Display figure
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))
